# %% [markdown]
# # fMRI data preprocessing

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/adasegroup/NEUROML2020/blob/seminar4/seminar-4/preprocessing.ipynb)

# %% [markdown]
# fMRI scans are saved in dicom format. For scientific analysis of brain images the nifty format (.nii files) are often used.
# The conversion from dicom to nifty can be done with [dcm2niix](https://www.nitrc.org/plugins/mwiki/index.php/dcm2nii:MainPage#Introduction)
#
# Many file are generated during fMRI sessions. These can arranged in many ways, thus a standard is needed how to arrange them.
# Commonly used standard is [Brain Imaging Data Structure (BIDS)](https://bids.neuroimaging.io/).
#
# You can use [HeuDiConv](https://heudiconv.readthedocs.io/en/latest/) or [Dcm2Bids](https://cbedetti.github.io/Dcm2Bids/tutorial/) to automate the conversion from dicom to BIDS.
#
# ![DICOM TO BIDS](https://www.incf.org/sites/default/files/articles/bids_standard-2.jpg)

# %% [markdown]
# Let's download the data we will be working with.

# %%
# %%bash
# datalad get -J 4 -d /data/ds000114 \
#     /data/ds000114/derivatives/fmriprep/sub-*/anat/*preproc.nii.gz \
#     /data/ds000114/sub-*/ses-test/func/*fingerfootlips*
# Out:
# action summary:
#   get (notneeded: 31)

# %%
from utils import list_files
# The data is already in BIDS format
# The subjects peformed 5 tasks. We will focus on fingerfootlips task
list_files('/data/ds000114/sub-01/ses-retest')
# Out:
# ses-retest/
#     dwi/
#         sub-01_ses-retest_dwi.nii.gz
#     anat/
#         sub-01_ses-retest_T1w.nii.gz
#     func/
#         sub-01_ses-retest_task-overtverbgeneration_bold.nii.gz
#         sub-01_ses-retest_task-covertverbgeneration_bold.nii.gz
#         sub-01_ses-retest_task-linebisection_bold.nii.gz
#         sub-01_ses-retest_task-fingerfootlips_bold.nii.gz
#         sub-01_ses-retest_task-overtwordrepetition_bold.nii.gz
#         sub-01_ses-retest_task-linebisection_events.tsv

# %%
# %%bash
# cd /data/ds000114/
# nib-ls derivatives/fmriprep/sub-01/*/*t1w_preproc.nii.gz sub-01/ses-test/f*/*fingerfootlips*.nii.gz
# Out:
# derivatives/fmriprep/sub-01/anat/sub-01_t1w_preproc.nii.gz           float32 [256, 156, 256]      1.00x1.30x1.00        sform
# sub-01/ses-test/func/sub-01_ses-test_task-fingerfootlips_bold.nii.gz  int16  [ 64,  64,  30, 184] 4.00x4.00x4.00x2.50   sform

# %% [markdown]
# With nibabel we can load a file and inspect its properties.

# %%
import nibabel
from nilearn import plotting
import numpy as np
import warnings
warnings.filterwarnings('ignore')

anat = nibabel.load('/data/ds000114/derivatives/fmriprep/sub-01/anat/sub-01_t1w_preproc.nii.gz')
fmri = nibabel.load('/data/ds000114/sub-01/ses-test/func/sub-01_ses-test_task-fingerfootlips_bold.nii.gz')

# %%
print(f'Anatomical dimensionality is {anat.ndim} and fmri is {fmri.ndim}')
#The anatomical image have higher resolution then the fmri
print(f'Anatomical voxelization:{anat.shape} fMRI voxelization:{fmri.shape}')
#the data can be accessed as
data = np.array(anat.dataobj)
# Out:
# Anatomical dimensionality is 3 and fmri is 4
# Anatomical voxelization:(256, 156, 256) fMRI voxelization:(64, 64, 30, 184)

# %%
import json

#metadata is located in json files
with open('/data/ds000114/task-fingerfootlips_bold.json', 'rt') as fp:
    task_info = json.load(fp)
task_info
# Out:
# {'EchoTime': 0.05,
#  'FlipAngle': 90,
#  'RepetitionTime': 2.5,
#  'SliceTiming': [0.0,
#   1.2499999999999998,
#   0.08333333333333333,
#   1.333333333333333,
#   0.16666666666666666,
#   1.4166666666666663,
#   0.25,
#   1.4999999999999996,
#   0.3333333333333333,
#   1.5833333333333328,
#   0.41666666666666663,
#   1.666666666666666,
#   0.5,
#   1.7499999999999993,
#   0.5833333333333333,
#   1.8333333333333326,
#   0.6666666666666666,
#   1.9166666666666659,
#   0.75,
#   1.9999999999999991,
#   0.8333333333333333,
#   2.083333333333332,
#   0.9166666666666666,
#   2.1666666666666656,
#   1.0,
#   2.249999999999999,
#   1.0833333333333333,
#   2.333333333333332,
#   1.1666666666666665,
#   2.416666666666665],
#  'TaskName': 'finger_foot_lips'}

# %%
len(task_info['SliceTiming'])
# Out:
# 30

# %% [markdown]
# # Introduction Nipype

# %% [markdown]
# **Why nipype?**
#
# Nipype allows to build preprocessing pipelines from different softwares, and it is computationally efficient. There are some helpful ready to use pipleines written with Nipype like [fmriprep](https://fmriprep.org/en/stable/index.html). To use fmriprep the data have to be in valid BIDS format. The user have to supply only the path to the data setup the [parametars](https://fmriprep.org/en/stable/usage.html#command-line-arguments).
#
# In Nipype, interfaces are python modules that allow you to use various external packages (e.g. FSL, SPM or FreeSurfer), even if they themselves are written in another programming language than python. Such an interface knows what sort of options an external program has and how to execute it.
#
# ![Nipype architecture](https://raw.github.com/satra/intro2nipype/master/images/arch.png)
#
# In Nipype, a node is an object that executes a certain function. This function can be anything from a Nipype interface to a user-specified function or an external script. Each node consists of a name, an interface category and at least one input field, and at least one output field.
#
#
# Once you connect multiple nodes to each other, you create a directed graph. In Nipype we call such graphs either workflows or pipelines. Directed connections can only be established from an output field of a node to an input field of another node.

# %%
from nipype import Node, Function, Workflow
from IPython.display import Image, clear_output


def multiply(a, b):
    return a * b

#Create a Node that multiplies 2 numbers
mul = Node(Function(input_names=['a', 'b'],
                      output_names=['multiply_result'],
                      function=multiply), 
             name='a_x_b')

mul.inputs.a = 2
mul.inputs.b = 3

result = mul.run()
result.outputs
# Out:
# 200920-23:36:10,141 nipype.workflow INFO:
# 	 [Node] Setting-up "a_x_b" in "/tmp/tmpr129nt7r/a_x_b".
# 200920-23:36:10,144 nipype.workflow INFO:
# 	 [Node] Running "a_x_b" ("nipype.interfaces.utility.wrappers.Function")
# 200920-23:36:10,152 nipype.workflow INFO:
# 	 [Node] Finished "a_x_b".
# multiply_result = 6

# %%
#Create a Node that adds 2 numbers
def add(a, b):
    return a + b



adder = Node(Function(input_names=['a', 'b'],
                      output_names=['add'],
                      function=add), 
             name='a_plus_b')
adder.inputs.b = 10

#Create a workflow 
wf = Workflow('hello')
# connect the nodes 
wf.connect(mul, 'multiply_result', adder, 'a')
#visualize the graph
wf.write_graph(graph2use='flat', format='png', simple_form=True)
clear_output()
Image(filename='graph_detailed.png')

# %%
#run the graph
eg = wf.run()
clear_output()#don't print the pipeline steps during exection
#chek the results
eg = list(eg.nodes())
nodes_outputs = [node.result.outputs for node in eg]
nodes_outputs
# Out:
# [
#  multiply_result = 6,
#
#  add = 16]

# %% [markdown]
# # Preprocessing
#
#
# In this workflow we will conduct the following steps:
#
# **1. Coregistration of functional images to anatomical images (according to FSL's FEAT pipeline)**

# %% [markdown]
# Co-registrationis the process of spatial alignment of 2 images. The target image is also called reference volume. The goodness of alignment is evaluated with a cost function.
#
# We have to move the fmri series from fmri native space:

# %%
_ = plotting.plot_anat(nibabel.nifti1.Nifti1Image(fmri.get_data()[:,:,:,1], affine=fmri.affine), cut_coords=(0,0,0), title='fmri slice')

# %% [markdown]
#  to native anatomical space:

# %%
_ = plotting.plot_anat(anat, cut_coords=(0,0,0), title='Anatomical image')

# %% [markdown]
# **2. Motion correction of functional images with FSL's MCFLIRT**
#
#  The images are aligned with rigid transformation - rotations, translations, reflections.
#  Then spatial interpolation is done, so as there was no movements.
#
# ![Rigit transformation](https://www.researchgate.net/profile/Olivier_Serres/publication/43808029/figure/fig4/AS:304436623757316@1449594755197/Rigid-body-transformation-scale-1.png)

# %% [markdown]
#  **3. Slice Timing correction**
#
#  The brain slices are not acquired at the same time. Therefore, interpolation is done between the nearest timepoints
# ![Slice Order](https://www.mccauslandcenter.sc.edu/crnl/sites/sc.edu.crnl/files/slice_order_1.jpg)
#
# [Slice timing corretion in python](https://matthew-brett.github.io/teaching/slice_timing.html)

# %% [markdown]
# **4. Smoothing of coregistered functional images with FWHM set to 5/10 mm**
#
# **5. Artifact Detection in functional images (to detect outlier volumes)**

# %% [markdown]
# **So, let's start!**

# %% [markdown]
# ## Imports
#
# First, let's import all the modules we later will be needing.

# %%
from nilearn import plotting
# %matplotlib inline
from os.path import join as opj
import os
import json
from nipype.interfaces.fsl import (BET, ExtractROI, FAST, FLIRT, ImageMaths,
                                   MCFLIRT, SliceTimer, Threshold)
from nipype.interfaces.spm import Smooth
from nipype.interfaces.utility import IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.algorithms.rapidart import ArtifactDetect
from nipype import Workflow, Node

# %% [markdown]
# ## Experiment parameters
#
# It's always a good idea to specify all parameters that might change between experiments at the beginning of your script. We will use one functional image for fingerfootlips task for ten subjects.

# %%
experiment_dir = '/output'
output_dir = 'datasink'
working_dir = 'workingdir'

# list of subject identifiers
subject_list = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10']

# list of session identifiers
task_list = ['fingerfootlips']

# Smoothing widths to apply
fwhm = [5, 10]

# TR of functional images(time from the application of an excitation pulse to the application of the next pulse)

with open('/data/ds000114/task-fingerfootlips_bold.json', 'rt') as fp:
    task_info = json.load(fp)
TR = task_info['RepetitionTime']

# Isometric resample of functional images to voxel size (in mm)
iso_size = 4

# %% [markdown]
# ## Specify Nodes for the main workflow
#
# Initiate all the different interfaces (represented as nodes) that you want to use in your workflow.

# %%
# ExtractROI - skip dummy scans
#t_min - Minimum index for t-dimension
#t_size - Size of ROI in t-dimension
extract = Node(ExtractROI(t_min=4, t_size=-1, output_type='NIFTI'),
               name="extract")

#MCFLIRT - motion correction
#https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/MCFLIRT
#mean_vol- volumes are averaged to create a new template
#normcorr cost - https://www.fmrib.ox.ac.uk/datasets/techrep/tr02mj1/tr02mj1/node4.html
#sinc interpolation - https://math.stackexchange.com/questions/1372632/how-does-sinc-interpolation-work
mcflirt = Node(MCFLIRT(mean_vol=True,
                       save_plots=True,
                       output_type='NIFTI'),
               name="mcflirt")

#SliceTimer - correct for slice wise acquisition
#https://poc.vl-e.nl/distribution/manual/fsl-3.2/slicetimer/index.html
#more on https://matthew-brett.github.io/teaching/slice_timing.html
#interleaved = -odd
#top to bottom = --down
#normcorr loss
slicetimer = Node(SliceTimer(index_dir=False,
                             interleaved=True,
                             output_type='NIFTI',
                             time_repetition=TR),
                  name="slicetimer")

#Smooth - image smoothing
#spm_smooth for 3D Gaussian smoothing
smooth = Node(Smooth(), name="smooth")
smooth.iterables = ("fwhm", fwhm)

# Artifact Detection - determines outliers in functional images via intensity and motion paramters
#http://web.mit.edu/swg/art/art.pdf
#norm_threshold - Threshold to use to detect motion-related outliers when composite motion is being used
#zintensity_threshold - Intensity Z-threshold use to detection images that deviate from the mean
#spm_global like calculation to determine the brain mask
#parameter_source - Source of movement parameters
#use_differences - Use differences between successive motion (first element) and
#intensity parameter (second element) estimates in order to determine outliers.

art = Node(ArtifactDetect(norm_threshold=2,
                          zintensity_threshold=3,
                          mask_type='spm_global',
                          parameter_source='FSL',
                          use_differences=[True, False],
                          plot_type='svg'),
           name="art")

# %% [markdown]
# ## Coregistration Workflow
#
# Initiate a workflow that coregistrates the functional images to the anatomical image (according to FSL's FEAT pipeline).

# %%
# BET - Skullstrip anatomical Image
#https://www.fmrib.ox.ac.uk/datasets/techrep/tr00ss2/tr00ss2.pdf

bet_anat = Node(BET(frac=0.5,
                    robust=True,
                    output_type='NIFTI_GZ'),
                name="bet_anat")

# FAST - Image Segmentation
#https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FAST
#http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.200.3832&rep=rep1&type=pdf

segmentation = Node(FAST(output_type='NIFTI_GZ'),
                    name="segmentation", mem_gb=4)

# Select WM segmentation file from segmentation output
def get_wm(files):
    return files[-1]

# Threshold - Threshold WM probability image
threshold = Node(Threshold(thresh=0.5,
                           args='-bin',
                           output_type='NIFTI_GZ'),
                name="threshold")

# FLIRT - pre-alignment of functional images to anatomical images
#https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FLIRT
coreg_pre = Node(FLIRT(dof=6, output_type='NIFTI_GZ'),
                 name="coreg_pre")

# FLIRT - coregistration of functional images to anatomical images with BBR(uses the segmentation)
#https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/FLIRT_BBR
coreg_bbr = Node(FLIRT(dof=6,
                       cost='bbr',
                       schedule=opj(os.getenv('FSLDIR'),
                                    'etc/flirtsch/bbr.sch'),
                       output_type='NIFTI_GZ'),
                 name="coreg_bbr")

# Apply coregistration warp to functional images
#apply_isoxfm-apply transformation supplied by in_matrix_file
applywarp = Node(FLIRT(interp='spline',
                       apply_isoxfm=iso_size,
                       output_type='NIFTI'),
                 name="applywarp")

# Apply coregistration wrap to mean file
applywarp_mean = Node(FLIRT(interp='spline',
                            apply_isoxfm=iso_size,
                            output_type='NIFTI_GZ'),
                 name="applywarp_mean")

# Create a coregistration workflow
coregwf = Workflow(name='coregwf')
coregwf.base_dir = opj(experiment_dir, working_dir)

# Connect all components of the coregistration workflow
coregwf.connect([(bet_anat, segmentation, [('out_file', 'in_files')]),
                 (segmentation, threshold, [(('partial_volume_files', get_wm),
                                             'in_file')]),
                 (bet_anat, coreg_pre, [('out_file', 'reference')]),
                 (threshold, coreg_bbr, [('out_file', 'wm_seg')]),
                 (coreg_pre, coreg_bbr, [('out_matrix_file', 'in_matrix_file')]),
                 (coreg_bbr, applywarp, [('out_matrix_file', 'in_matrix_file')]),
                 (bet_anat, applywarp, [('out_file', 'reference')]),
                 (coreg_bbr, applywarp_mean, [('out_matrix_file', 'in_matrix_file')]),
                 (bet_anat, applywarp_mean, [('out_file', 'reference')]),
                 ])

# %% [markdown]
# ## Specify input & output stream
#
# Specify where the input data can be found & where and how to save the output data.

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id', 'task_name']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('task_name', task_list)]

# SelectFiles - to grab the data 
anat_file = opj('derivatives', 'fmriprep', 'sub-{subject_id}', 'anat', 'sub-{subject_id}_t1w_preproc.nii.gz')
func_file = opj('sub-{subject_id}', 'ses-test', 'func',
                'sub-{subject_id}_ses-test_task-{task_name}_bold.nii.gz')

templates = {'anat': anat_file,
             'func': func_file}
selectfiles = Node(SelectFiles(templates,
                               base_directory='/data/ds000114'),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

## Use the following DataSink output substitutions
substitutions = [('_subject_id_', 'sub-'),
                 ('_task_name_', '/task-'),
                 ('_fwhm_', 'fwhm-'),
                 ('_roi', ''),
                 ('_mcf', ''),
                 ('_st', ''),
                 ('_flirt', ''),
                 ('.nii_mean_reg', '_mean'),
                 ('.nii.par', '.par'),
                 ]
subjFolders = [('fwhm-%s/' % f, 'fwhm-%s_' % f) for f in fwhm]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ## Specify Workflow
#
# Create a workflow and connect the interface nodes and the I/O stream to each other.

# %%
# Create a preprocessing workflow
preproc = Workflow(name='preproc')
preproc.base_dir = opj(experiment_dir, working_dir)

# Connect all components of the preprocessing workflow
preproc.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                            ('task_name', 'task_name')]),
                 (selectfiles, extract, [('func', 'in_file')]),
                 (extract, mcflirt, [('roi_file', 'in_file')]),
                 (mcflirt, slicetimer, [('out_file', 'in_file')]),

                 (selectfiles, coregwf, [('anat', 'bet_anat.in_file'),
                                         ('anat', 'coreg_bbr.reference')]),
                 (mcflirt, coregwf, [('mean_img', 'coreg_pre.in_file'),
                                     ('mean_img', 'coreg_bbr.in_file'),
                                     ('mean_img', 'applywarp_mean.in_file')]),
                 (slicetimer, coregwf, [('slice_time_corrected_file', 'applywarp.in_file')]),
                 
                 (coregwf, smooth, [('applywarp.out_file', 'in_files')]),

                 (mcflirt, datasink, [('par_file', 'preproc.@par')]),
                 (smooth, datasink, [('smoothed_files', 'preproc.@smooth')]),
                 (coregwf, datasink, [('applywarp_mean.out_file', 'preproc.@mean')]),

                 (coregwf, art, [('applywarp.out_file', 'realigned_files')]),
                 (mcflirt, art, [('par_file', 'realignment_parameters')]),

                 (coregwf, datasink, [('coreg_bbr.out_matrix_file', 'preproc.@mat_file'),
                                      ('bet_anat.out_file', 'preproc.@brain')]),
                 (art, datasink, [('outlier_files', 'preproc.@outlier_files'),
                                  ('plot_files', 'preproc.@plot_files')]),
                 ])

# %% [markdown]
# ## Visualize the workflow
#
# It always helps to visualize your workflow.

# %%
# Create preproc output graph
preproc.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(preproc.base_dir, 'preproc', 'graph.png'))
# Out:
# 200920-23:36:15,520 nipype.workflow INFO:
# 	 Generated workflow graph: /output/workingdir/preproc/graph.png (graph2use=colored, simple_form=True).

# %%
# Visualize the detailed graph
preproc.write_graph(graph2use='flat', format='png', simple_form=True)
Image(filename=opj(preproc.base_dir, 'preproc', 'graph_detailed.png'))
# Out:
# 200920-23:36:16,77 nipype.workflow INFO:
# 	 Generated workflow graph: /output/workingdir/preproc/graph.png (graph2use=flat, simple_form=True).

# %% [markdown]
# ##  Run the Workflow
#
# Now that everything is ready, we can run the preprocessing workflow. Change ``n_procs`` to the number of jobs/cores you want to use. **Note** that if  you're using a Docker container and FLIRT fails to run without any good reason, you might need to change memory settings in the Docker preferences (6 GB should be enough for this workflow).

# %%
preproc.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 200920-23:36:16,164 nipype.workflow INFO:
# 	 Workflow preproc settings: ['check', 'execution', 'logging', 'monitoring']
# 200920-23:36:16,256 nipype.workflow INFO:
# 	 Running in parallel.
# 200920-23:36:16,262 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:16,335 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_10_task_name_fingerfootlips/selectfiles".200920-23:36:16,336 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_09_task_name_fingerfootlips/selectfiles".
#
# 200920-23:36:16,338 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_08_task_name_fingerfootlips/selectfiles".
# 200920-23:36:16,346 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200920-23:36:16,347 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")200920-23:36:16,348 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 200920-23:36:16,351 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:36:16,352 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:36:16,354 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:36:16,338 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_07_task_name_fingerfootlips/selectfiles".
# 200920-23:36:16,394 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200920-23:36:16,400 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:36:18,265 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc.selectfiles).
# 200920-23:36:18,268 nipype.workflow INFO:
# 	 [Job 16] Completed (preproc.selectfiles).
# 200920-23:36:18,274 nipype.workflow INFO:
# 	 [Job 32] Completed (preproc.selectfiles).
# 200920-23:36:18,276 nipype.workflow INFO:
# 	 [Job 48] Completed (preproc.selectfiles).
# 200920-23:36:18,280 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 14 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:18,350 nipype.workflow INFO:
# 	 [Job 1] Cached (preproc.coregwf.bet_anat).
# 200920-23:36:18,353 nipype.workflow INFO:
# 	 [Job 4] Cached (preproc.extract).
# 200920-23:36:18,357 nipype.workflow INFO:
# 	 [Job 17] Cached (preproc.coregwf.bet_anat).
# 200920-23:36:18,360 nipype.workflow INFO:
# 	 [Job 20] Cached (preproc.extract).
# 200920-23:36:20,340 nipype.workflow INFO:
# 	 [Job 2] Cached (preproc.coregwf.segmentation).
# 200920-23:36:20,344 nipype.workflow INFO:
# 	 [Job 5] Cached (preproc.mcflirt).
# 200920-23:36:20,347 nipype.workflow INFO:
# 	 [Job 18] Cached (preproc.coregwf.segmentation).
# 200920-23:36:20,351 nipype.workflow INFO:
# 	 [Job 21] Cached (preproc.mcflirt).
# 200920-23:36:22,271 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:22,344 nipype.workflow INFO:
# 	 [Job 3] Cached (preproc.coregwf.threshold).
# 200920-23:36:22,348 nipype.workflow INFO:
# 	 [Job 6] Cached (preproc.coregwf.coreg_pre).
# 200920-23:36:22,352 nipype.workflow INFO:
# 	 [Job 9] Cached (preproc.slicetimer).
# 200920-23:36:22,356 nipype.workflow INFO:
# 	 [Job 19] Cached (preproc.coregwf.threshold).
# 200920-23:36:24,273 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:24,351 nipype.workflow INFO:
# 	 [Job 7] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:36:24,355 nipype.workflow INFO:
# 	 [Job 22] Cached (preproc.coregwf.coreg_pre).
# 200920-23:36:24,358 nipype.workflow INFO:
# 	 [Job 25] Cached (preproc.slicetimer).
# 200920-23:36:24,361 nipype.workflow INFO:
# 	 [Job 33] Cached (preproc.coregwf.bet_anat).
# 200920-23:36:26,353 nipype.workflow INFO:
# 	 [Job 8] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:36:26,358 nipype.workflow INFO:
# 	 [Job 10] Cached (preproc.coregwf.applywarp).
# 200920-23:36:26,362 nipype.workflow INFO:
# 	 [Job 23] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:36:26,365 nipype.workflow INFO:
# 	 [Job 34] Cached (preproc.coregwf.segmentation).
# 200920-23:36:28,277 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 15 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:28,348 nipype.workflow INFO:
# 	 [Job 11] Cached (preproc.smooth).
# 200920-23:36:28,352 nipype.workflow INFO:
# 	 [Job 12] Cached (preproc.smooth).
# 200920-23:36:28,355 nipype.workflow INFO:
# 	 [Job 13] Cached (preproc.art).
# 200920-23:36:28,359 nipype.workflow INFO:
# 	 [Job 24] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:36:30,278 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:30,359 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_10_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:36:30,367 nipype.workflow INFO:
# 	 [Job 26] Cached (preproc.coregwf.applywarp).
# 200920-23:36:30,367 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_10_task_name_fingerfootlips/_fwhm_5/datasink".
# 200920-23:36:30,371 nipype.workflow INFO:
# 	 [Job 35] Cached (preproc.coregwf.threshold).
# 200920-23:36:30,370 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:36:30,373 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold.par
# 200920-23:36:30,374 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/art.sub-10_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-10/task-fingerfootlips/art.sub-10_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:36:30,376 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/plot.sub-10_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-10/task-fingerfootlips/plot.sub-10_ses-test_task-fingerfootlips_bold.svg
# 200920-23:36:30,376 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:36:30,377 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_t1w_preproc_brain.nii.gz
# 200920-23:36:30,380 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_mean.mat200920-23:36:30,381 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold.par
#
# 200920-23:36:30,383 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_mean.nii.gz200920-23:36:30,383 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/art.sub-10_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-10/task-fingerfootlips/art.sub-10_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:36:30,385 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/_fwhm_10/ssub-10_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-10/task-fingerfootlips/fwhm-10_ssub-10_ses-test_task-fingerfootlips_bold.nii
#
# 200920-23:36:30,386 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/plot.sub-10_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-10/task-fingerfootlips/plot.sub-10_ses-test_task-fingerfootlips_bold.svg
# 200920-23:36:30,387 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_t1w_preproc_brain.nii.gz
# 200920-23:36:30,389 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".200920-23:36:30,389 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_mean.mat
#
# 200920-23:36:30,391 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-10/task-fingerfootlips/sub-10_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:36:30,393 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_10_task_name_fingerfootlips/_fwhm_5/ssub-10_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-10/task-fingerfootlips/fwhm-5_ssub-10_ses-test_task-fingerfootlips_bold.nii
# 200920-23:36:30,397 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:36:32,277 nipype.workflow INFO:
# 	 [Job 14] Completed (preproc.datasink).
# 200920-23:36:32,280 nipype.workflow INFO:
# 	 [Job 15] Completed (preproc.datasink).
# 200920-23:36:32,285 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:32,357 nipype.workflow INFO:
# 	 [Job 27] Cached (preproc.smooth).
# 200920-23:36:32,363 nipype.workflow INFO:
# 	 [Job 28] Cached (preproc.smooth).
# 200920-23:36:32,371 nipype.workflow INFO:
# 	 [Job 29] Cached (preproc.art).
# 200920-23:36:32,373 nipype.workflow INFO:
# 	 [Job 36] Cached (preproc.extract).
# 200920-23:36:34,282 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:34,362 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_09_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:36:34,368 nipype.workflow INFO:
# 	 [Job 37] Cached (preproc.mcflirt).
# 200920-23:36:34,368 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_09_task_name_fingerfootlips/_fwhm_5/datasink".
# 200920-23:36:34,373 nipype.workflow INFO:
# 	 [Job 49] Cached (preproc.coregwf.bet_anat).
# 200920-23:36:34,373 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:36:34,375 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:36:34,378 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold.par200920-23:36:34,378 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold.par
#
# 200920-23:36:34,380 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/art.sub-09_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-09/task-fingerfootlips/art.sub-09_ses-test_task-fingerfootlips_bold_outliers.txt200920-23:36:34,380 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/art.sub-09_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-09/task-fingerfootlips/art.sub-09_ses-test_task-fingerfootlips_bold_outliers.txt
#
# 200920-23:36:34,381 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/plot.sub-09_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-09/task-fingerfootlips/plot.sub-09_ses-test_task-fingerfootlips_bold.svg
# 200920-23:36:34,382 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/plot.sub-09_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-09/task-fingerfootlips/plot.sub-09_ses-test_task-fingerfootlips_bold.svg200920-23:36:34,383 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_t1w_preproc_brain.nii.gz
#
# 200920-23:36:34,384 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_t1w_preproc_brain.nii.gz
# 200920-23:36:34,385 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:36:34,386 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:36:34,387 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_mean.nii.gz200920-23:36:34,387 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-09/task-fingerfootlips/sub-09_ses-test_task-fingerfootlips_bold_mean.nii.gz
#
# 200920-23:36:34,389 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/_fwhm_5/ssub-09_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-09/task-fingerfootlips/fwhm-5_ssub-09_ses-test_task-fingerfootlips_bold.nii200920-23:36:34,389 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_09_task_name_fingerfootlips/_fwhm_10/ssub-09_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-09/task-fingerfootlips/fwhm-10_ssub-09_ses-test_task-fingerfootlips_bold.nii
#
# 200920-23:36:34,394 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:36:34,395 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:36:36,280 nipype.workflow INFO:
# 	 [Job 30] Completed (preproc.datasink).
# 200920-23:36:36,282 nipype.workflow INFO:
# 	 [Job 31] Completed (preproc.datasink).
# 200920-23:36:36,286 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:36,356 nipype.workflow INFO:
# 	 [Job 38] Cached (preproc.coregwf.coreg_pre).
# 200920-23:36:36,359 nipype.workflow INFO:
# 	 [Job 41] Cached (preproc.slicetimer).
# 200920-23:36:36,362 nipype.workflow INFO:
# 	 [Job 50] Cached (preproc.coregwf.segmentation).
# 200920-23:36:36,364 nipype.workflow INFO:
# 	 [Job 52] Cached (preproc.extract).
# 200920-23:36:38,286 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:38,360 nipype.workflow INFO:
# 	 [Job 39] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:36:38,364 nipype.workflow INFO:
# 	 [Job 51] Cached (preproc.coregwf.threshold).
# 200920-23:36:38,367 nipype.workflow INFO:
# 	 [Job 53] Cached (preproc.mcflirt).
# 200920-23:36:38,371 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_06_task_name_fingerfootlips/selectfiles".
# 200920-23:36:38,377 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200920-23:36:38,383 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:36:40,285 nipype.workflow INFO:
# 	 [Job 64] Completed (preproc.selectfiles).
# 200920-23:36:40,291 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:40,364 nipype.workflow INFO:
# 	 [Job 40] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:36:40,368 nipype.workflow INFO:
# 	 [Job 42] Cached (preproc.coregwf.applywarp).
# 200920-23:36:40,372 nipype.workflow INFO:
# 	 [Job 54] Cached (preproc.coregwf.coreg_pre).
# 200920-23:36:40,375 nipype.workflow INFO:
# 	 [Job 57] Cached (preproc.slicetimer).
# 200920-23:36:42,361 nipype.workflow INFO:
# 	 [Job 43] Cached (preproc.smooth).
# 200920-23:36:42,364 nipype.workflow INFO:
# 	 [Job 44] Cached (preproc.smooth).
# 200920-23:36:42,368 nipype.workflow INFO:
# 	 [Job 45] Cached (preproc.art).
# 200920-23:36:42,373 nipype.workflow INFO:
# 	 [Job 55] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:36:44,377 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_08_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:36:44,384 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_08_task_name_fingerfootlips/_fwhm_5/datasink".
# 200920-23:36:44,388 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:36:44,391 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:36:44,392 nipype.workflow INFO:
# 	 [Job 56] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:36:44,393 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold.par
# 200920-23:36:44,393 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold.par
# 200920-23:36:44,395 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/art.sub-08_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-08/task-fingerfootlips/art.sub-08_ses-test_task-fingerfootlips_bold_outliers.txt200920-23:36:44,396 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/art.sub-08_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-08/task-fingerfootlips/art.sub-08_ses-test_task-fingerfootlips_bold_outliers.txt
#
# 200920-23:36:44,399 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/plot.sub-08_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-08/task-fingerfootlips/plot.sub-08_ses-test_task-fingerfootlips_bold.svg200920-23:36:44,399 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/plot.sub-08_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-08/task-fingerfootlips/plot.sub-08_ses-test_task-fingerfootlips_bold.svg200920-23:36:44,403 nipype.workflow INFO:
# 	 [Job 58] Cached (preproc.coregwf.applywarp).
#
#
# 200920-23:36:44,401 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_t1w_preproc_brain.nii.gz
# 200920-23:36:44,400 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_t1w_preproc_brain.nii.gz
# 200920-23:36:44,402 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:36:44,404 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:36:44,405 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:36:44,406 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-08/task-fingerfootlips/sub-08_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:36:44,407 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/_fwhm_5/ssub-08_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-08/task-fingerfootlips/fwhm-5_ssub-08_ses-test_task-fingerfootlips_bold.nii200920-23:36:44,408 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_08_task_name_fingerfootlips/_fwhm_10/ssub-08_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-08/task-fingerfootlips/fwhm-10_ssub-08_ses-test_task-fingerfootlips_bold.nii
#
# 200920-23:36:44,413 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:36:44,413 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:36:46,291 nipype.workflow INFO:
# 	 [Job 46] Completed (preproc.datasink).
# 200920-23:36:46,295 nipype.workflow INFO:
# 	 [Job 47] Completed (preproc.datasink).
# 200920-23:36:46,301 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:46,371 nipype.workflow INFO:
# 	 [Job 59] Cached (preproc.smooth).
# 200920-23:36:46,374 nipype.workflow INFO:
# 	 [Job 60] Cached (preproc.smooth).
# 200920-23:36:46,378 nipype.workflow INFO:
# 	 [Job 61] Cached (preproc.art).
# 200920-23:36:46,381 nipype.workflow INFO:
# 	 [Job 65] Cached (preproc.coregwf.bet_anat).
# 200920-23:36:48,296 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:48,376 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_07_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:36:48,388 nipype.workflow INFO:
# 	 [Job 66] Cached (preproc.coregwf.segmentation).
# 200920-23:36:48,388 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")200920-23:36:48,388 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_07_task_name_fingerfootlips/_fwhm_5/datasink".
#
# 200920-23:36:48,391 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold.par
# 200920-23:36:48,393 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/art.sub-07_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-07/task-fingerfootlips/art.sub-07_ses-test_task-fingerfootlips_bold_outliers.txt200920-23:36:48,395 nipype.workflow INFO:
# 	 [Job 68] Cached (preproc.extract).
#
# 200920-23:36:48,395 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/plot.sub-07_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-07/task-fingerfootlips/plot.sub-07_ses-test_task-fingerfootlips_bold.svg
# 200920-23:36:48,397 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_t1w_preproc_brain.nii.gz
# 200920-23:36:48,399 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:36:48,400 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")200920-23:36:48,400 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_mean.nii.gz
#
# 200920-23:36:48,402 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/_fwhm_10/ssub-07_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-07/task-fingerfootlips/fwhm-10_ssub-07_ses-test_task-fingerfootlips_bold.nii200920-23:36:48,403 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold.par
#
# 200920-23:36:48,404 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/art.sub-07_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-07/task-fingerfootlips/art.sub-07_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:36:48,406 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/plot.sub-07_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-07/task-fingerfootlips/plot.sub-07_ses-test_task-fingerfootlips_bold.svg
# 200920-23:36:48,407 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".200920-23:36:48,407 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_t1w_preproc_brain.nii.gz
#
# 200920-23:36:48,409 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:36:48,411 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-07/task-fingerfootlips/sub-07_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:36:48,413 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_07_task_name_fingerfootlips/_fwhm_5/ssub-07_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-07/task-fingerfootlips/fwhm-5_ssub-07_ses-test_task-fingerfootlips_bold.nii
# 200920-23:36:48,418 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:36:50,295 nipype.workflow INFO:
# 	 [Job 62] Completed (preproc.datasink).
# 200920-23:36:50,299 nipype.workflow INFO:
# 	 [Job 63] Completed (preproc.datasink).
# 200920-23:36:50,304 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:50,375 nipype.workflow INFO:
# 	 [Job 67] Cached (preproc.coregwf.threshold).
# 200920-23:36:50,378 nipype.workflow INFO:
# 	 [Job 69] Cached (preproc.mcflirt).
# 200920-23:36:50,382 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_05_task_name_fingerfootlips/selectfiles".
# 200920-23:36:50,383 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_04_task_name_fingerfootlips/selectfiles".
# 200920-23:36:50,389 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")200920-23:36:50,391 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 200920-23:36:50,395 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:36:50,396 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:36:52,297 nipype.workflow INFO:
# 	 [Job 80] Completed (preproc.selectfiles).
# 200920-23:36:52,301 nipype.workflow INFO:
# 	 [Job 96] Completed (preproc.selectfiles).
# 200920-23:36:52,307 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:52,379 nipype.workflow INFO:
# 	 [Job 70] Cached (preproc.coregwf.coreg_pre).
# 200920-23:36:52,383 nipype.workflow INFO:
# 	 [Job 73] Cached (preproc.slicetimer).
# 200920-23:36:52,386 nipype.workflow INFO:
# 	 [Job 81] Cached (preproc.coregwf.bet_anat).
# 200920-23:36:52,389 nipype.workflow INFO:
# 	 [Job 84] Cached (preproc.extract).
# 200920-23:36:54,302 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:54,384 nipype.workflow INFO:
# 	 [Job 71] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:36:54,387 nipype.workflow INFO:
# 	 [Job 82] Cached (preproc.coregwf.segmentation).
# 200920-23:36:54,390 nipype.workflow INFO:
# 	 [Job 85] Cached (preproc.mcflirt).
# 200920-23:36:54,393 nipype.workflow INFO:
# 	 [Job 97] Cached (preproc.coregwf.bet_anat).
# 200920-23:36:56,304 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:36:56,381 nipype.workflow INFO:
# 	 [Job 72] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:36:56,385 nipype.workflow INFO:
# 	 [Job 74] Cached (preproc.coregwf.applywarp).
# 200920-23:36:56,388 nipype.workflow INFO:
# 	 [Job 83] Cached (preproc.coregwf.threshold).
# 200920-23:36:56,392 nipype.workflow INFO:
# 	 [Job 86] Cached (preproc.coregwf.coreg_pre).
# 200920-23:36:58,377 nipype.workflow INFO:
# 	 [Job 75] Cached (preproc.smooth).
# 200920-23:36:58,380 nipype.workflow INFO:
# 	 [Job 76] Cached (preproc.smooth).
# 200920-23:36:58,384 nipype.workflow INFO:
# 	 [Job 77] Cached (preproc.art).
# 200920-23:36:58,389 nipype.workflow INFO:
# 	 [Job 87] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:37:00,307 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:00,385 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_06_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:37:00,393 nipype.workflow INFO:
# 	 [Job 88] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:37:00,393 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_06_task_name_fingerfootlips/_fwhm_5/datasink".
# 200920-23:37:00,395 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:37:00,398 nipype.workflow INFO:
# 	 [Job 89] Cached (preproc.slicetimer).
# 200920-23:37:00,399 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold.par
# 200920-23:37:00,402 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/art.sub-06_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-06/task-fingerfootlips/art.sub-06_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:37:00,403 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:37:00,404 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/plot.sub-06_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-06/task-fingerfootlips/plot.sub-06_ses-test_task-fingerfootlips_bold.svg
# 200920-23:37:00,405 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold.par200920-23:37:00,406 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_t1w_preproc_brain.nii.gz
#
# 200920-23:37:00,407 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:37:00,409 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_mean.nii.gz200920-23:37:00,408 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/art.sub-06_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-06/task-fingerfootlips/art.sub-06_ses-test_task-fingerfootlips_bold_outliers.txt
#
# 200920-23:37:00,411 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/_fwhm_10/ssub-06_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-06/task-fingerfootlips/fwhm-10_ssub-06_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:00,413 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/plot.sub-06_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-06/task-fingerfootlips/plot.sub-06_ses-test_task-fingerfootlips_bold.svg
# 200920-23:37:00,416 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_t1w_preproc_brain.nii.gz
# 200920-23:37:00,417 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".200920-23:37:00,417 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_mean.mat
#
# 200920-23:37:00,420 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-06/task-fingerfootlips/sub-06_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:37:00,421 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_06_task_name_fingerfootlips/_fwhm_5/ssub-06_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-06/task-fingerfootlips/fwhm-5_ssub-06_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:00,425 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:37:02,307 nipype.workflow INFO:
# 	 [Job 78] Completed (preproc.datasink).
# 200920-23:37:02,311 nipype.workflow INFO:
# 	 [Job 79] Completed (preproc.datasink).
# 200920-23:37:02,316 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:02,388 nipype.workflow INFO:
# 	 [Job 90] Cached (preproc.coregwf.applywarp).
# 200920-23:37:02,391 nipype.workflow INFO:
# 	 [Job 98] Cached (preproc.coregwf.segmentation).
# 200920-23:37:02,394 nipype.workflow INFO:
# 	 [Job 100] Cached (preproc.extract).
# 200920-23:37:02,398 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_03_task_name_fingerfootlips/selectfiles".
# 200920-23:37:02,405 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200920-23:37:02,412 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:37:04,309 nipype.workflow INFO:
# 	 [Job 112] Completed (preproc.selectfiles).
# 200920-23:37:04,315 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:04,387 nipype.workflow INFO:
# 	 [Job 91] Cached (preproc.smooth).
# 200920-23:37:04,390 nipype.workflow INFO:
# 	 [Job 92] Cached (preproc.smooth).
# 200920-23:37:04,394 nipype.workflow INFO:
# 	 [Job 93] Cached (preproc.art).
# 200920-23:37:04,397 nipype.workflow INFO:
# 	 [Job 99] Cached (preproc.coregwf.threshold).
# 200920-23:37:06,314 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:06,403 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_05_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:37:06,414 nipype.workflow INFO:
# 	 [Job 101] Cached (preproc.mcflirt).
# 200920-23:37:06,413 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_05_task_name_fingerfootlips/_fwhm_5/datasink".200920-23:37:06,414 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 200920-23:37:06,417 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold.par
# 200920-23:37:06,419 nipype.workflow INFO:
# 	 [Job 113] Cached (preproc.coregwf.bet_anat).
# 200920-23:37:06,418 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/art.sub-05_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-05/task-fingerfootlips/art.sub-05_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:37:06,421 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/plot.sub-05_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-05/task-fingerfootlips/plot.sub-05_ses-test_task-fingerfootlips_bold.svg
# 200920-23:37:06,422 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")200920-23:37:06,422 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_t1w_preproc_brain.nii.gz
#
# 200920-23:37:06,424 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:37:06,425 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:37:06,426 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold.par
# 200920-23:37:06,427 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/_fwhm_10/ssub-05_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-05/task-fingerfootlips/fwhm-10_ssub-05_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:06,428 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/art.sub-05_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-05/task-fingerfootlips/art.sub-05_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:37:06,431 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".200920-23:37:06,432 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/plot.sub-05_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-05/task-fingerfootlips/plot.sub-05_ses-test_task-fingerfootlips_bold.svg
# 200920-23:37:06,434 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_t1w_preproc_brain.nii.gz
#
# 200920-23:37:06,435 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:37:06,437 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-05/task-fingerfootlips/sub-05_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:37:06,439 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_05_task_name_fingerfootlips/_fwhm_5/ssub-05_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-05/task-fingerfootlips/fwhm-5_ssub-05_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:06,444 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:37:08,313 nipype.workflow INFO:
# 	 [Job 94] Completed (preproc.datasink).
# 200920-23:37:08,317 nipype.workflow INFO:
# 	 [Job 95] Completed (preproc.datasink).
# 200920-23:37:08,323 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:08,394 nipype.workflow INFO:
# 	 [Job 102] Cached (preproc.coregwf.coreg_pre).
# 200920-23:37:08,397 nipype.workflow INFO:
# 	 [Job 105] Cached (preproc.slicetimer).
# 200920-23:37:08,400 nipype.workflow INFO:
# 	 [Job 114] Cached (preproc.coregwf.segmentation).
# 200920-23:37:08,403 nipype.workflow INFO:
# 	 [Job 116] Cached (preproc.extract).
# 200920-23:37:10,318 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:10,394 nipype.workflow INFO:
# 	 [Job 103] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:37:10,399 nipype.workflow INFO:
# 	 [Job 115] Cached (preproc.coregwf.threshold).
# 200920-23:37:10,405 nipype.workflow INFO:
# 	 [Job 117] Cached (preproc.mcflirt).
# 200920-23:37:10,412 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_02_task_name_fingerfootlips/selectfiles".
# 200920-23:37:10,419 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200920-23:37:10,427 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:37:12,317 nipype.workflow INFO:
# 	 [Job 128] Completed (preproc.selectfiles).
# 200920-23:37:12,323 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:12,398 nipype.workflow INFO:
# 	 [Job 104] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:37:12,403 nipype.workflow INFO:
# 	 [Job 106] Cached (preproc.coregwf.applywarp).
# 200920-23:37:12,406 nipype.workflow INFO:
# 	 [Job 118] Cached (preproc.coregwf.coreg_pre).
# 200920-23:37:12,409 nipype.workflow INFO:
# 	 [Job 121] Cached (preproc.slicetimer).
# 200920-23:37:14,402 nipype.workflow INFO:
# 	 [Job 107] Cached (preproc.smooth).
# 200920-23:37:14,405 nipype.workflow INFO:
# 	 [Job 108] Cached (preproc.smooth).
# 200920-23:37:14,409 nipype.workflow INFO:
# 	 [Job 109] Cached (preproc.art).
# 200920-23:37:14,414 nipype.workflow INFO:
# 	 [Job 119] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:37:16,398 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_04_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:37:16,405 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:37:16,406 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_04_task_name_fingerfootlips/_fwhm_5/datasink".200920-23:37:16,408 nipype.workflow INFO:
# 	 [Job 120] Cached (preproc.coregwf.applywarp_mean).
#
# 200920-23:37:16,408 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_04_task_name_fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-04/task-fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold.par
# 200920-23:37:16,412 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_04_task_name_fingerfootlips/art.sub-04_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-04/task-fingerfootlips/art.sub-04_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:37:16,414 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_04_task_name_fingerfootlips/plot.sub-04_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-04/task-fingerfootlips/plot.sub-04_ses-test_task-fingerfootlips_bold.svg200920-23:37:16,415 nipype.workflow INFO:
# 	 [Job 122] Cached (preproc.coregwf.applywarp).
#
# 200920-23:37:16,419 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")200920-23:37:16,418 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_04_task_name_fingerfootlips/sub-04_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-04/task-fingerfootlips/sub-04_t1w_preproc_brain.nii.gz
# 200920-23:37:16,421 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_04_task_name_fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-04/task-fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold_mean.mat
#
# 200920-23:37:16,423 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_04_task_name_fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-04/task-fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:37:16,424 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_04_task_name_fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-04/task-fingerfootlips/sub-04_ses-test_task-fingerfootlips_bold.par200920-23:37:16,425 nipype.interface INFO:
# ...
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/sub-03_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-03/task-fingerfootlips/sub-03_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:37:20,434 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/art.sub-03_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-03/task-fingerfootlips/art.sub-03_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:37:20,435 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/_fwhm_10/ssub-03_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-03/task-fingerfootlips/fwhm-10_ssub-03_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:20,436 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/plot.sub-03_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-03/task-fingerfootlips/plot.sub-03_ses-test_task-fingerfootlips_bold.svg
# 200920-23:37:20,438 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/sub-03_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-03/task-fingerfootlips/sub-03_t1w_preproc_brain.nii.gz
# 200920-23:37:20,440 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".200920-23:37:20,439 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/sub-03_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-03/task-fingerfootlips/sub-03_ses-test_task-fingerfootlips_bold_mean.mat
#
# 200920-23:37:20,443 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/sub-03_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-03/task-fingerfootlips/sub-03_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:37:20,444 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_03_task_name_fingerfootlips/_fwhm_5/ssub-03_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-03/task-fingerfootlips/fwhm-5_ssub-03_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:20,450 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:37:22,328 nipype.workflow INFO:
# 	 [Job 126] Completed (preproc.datasink).
# 200920-23:37:22,331 nipype.workflow INFO:
# 	 [Job 127] Completed (preproc.datasink).
# 200920-23:37:22,337 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:22,412 nipype.workflow INFO:
# 	 [Job 131] Cached (preproc.coregwf.threshold).
# 200920-23:37:22,415 nipype.workflow INFO:
# 	 [Job 133] Cached (preproc.mcflirt).
# 200920-23:37:22,419 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/output/workingdir/preproc/_subject_id_01_task_name_fingerfootlips/selectfiles".
# 200920-23:37:22,424 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200920-23:37:22,431 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200920-23:37:24,330 nipype.workflow INFO:
# 	 [Job 144] Completed (preproc.selectfiles).
# 200920-23:37:24,335 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:24,407 nipype.workflow INFO:
# 	 [Job 134] Cached (preproc.coregwf.coreg_pre).
# 200920-23:37:24,410 nipype.workflow INFO:
# 	 [Job 137] Cached (preproc.slicetimer).
# 200920-23:37:24,413 nipype.workflow INFO:
# 	 [Job 145] Cached (preproc.coregwf.bet_anat).
# 200920-23:37:24,416 nipype.workflow INFO:
# 	 [Job 148] Cached (preproc.extract).
# 200920-23:37:26,334 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:26,408 nipype.workflow INFO:
# 	 [Job 135] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:37:26,411 nipype.workflow INFO:
# 	 [Job 146] Cached (preproc.coregwf.segmentation).
# 200920-23:37:26,414 nipype.workflow INFO:
# 	 [Job 149] Cached (preproc.mcflirt).
# 200920-23:37:28,336 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:28,413 nipype.workflow INFO:
# 	 [Job 136] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:37:28,417 nipype.workflow INFO:
# 	 [Job 138] Cached (preproc.coregwf.applywarp).
# 200920-23:37:28,421 nipype.workflow INFO:
# 	 [Job 147] Cached (preproc.coregwf.threshold).
# 200920-23:37:28,424 nipype.workflow INFO:
# 	 [Job 150] Cached (preproc.coregwf.coreg_pre).
# 200920-23:37:30,409 nipype.workflow INFO:
# 	 [Job 139] Cached (preproc.smooth).
# 200920-23:37:30,413 nipype.workflow INFO:
# 	 [Job 140] Cached (preproc.smooth).
# 200920-23:37:30,416 nipype.workflow INFO:
# 	 [Job 141] Cached (preproc.art).
# 200920-23:37:30,421 nipype.workflow INFO:
# 	 [Job 151] Cached (preproc.coregwf.coreg_bbr).
# 200920-23:37:32,340 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:32,421 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_02_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:37:32,430 nipype.workflow INFO:
# 	 [Job 152] Cached (preproc.coregwf.applywarp_mean).
# 200920-23:37:32,429 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_02_task_name_fingerfootlips/_fwhm_5/datasink".
# 200920-23:37:32,432 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:37:32,435 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")200920-23:37:32,435 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold.par200920-23:37:32,437 nipype.workflow INFO:
# 	 [Job 153] Cached (preproc.slicetimer).
#
#
# 200920-23:37:32,437 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/art.sub-02_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-02/task-fingerfootlips/art.sub-02_ses-test_task-fingerfootlips_bold_outliers.txt200920-23:37:32,438 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold.par
#
# 200920-23:37:32,440 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/art.sub-02_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-02/task-fingerfootlips/art.sub-02_ses-test_task-fingerfootlips_bold_outliers.txt200920-23:37:32,440 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/plot.sub-02_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-02/task-fingerfootlips/plot.sub-02_ses-test_task-fingerfootlips_bold.svg
#
# 200920-23:37:32,442 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/plot.sub-02_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-02/task-fingerfootlips/plot.sub-02_ses-test_task-fingerfootlips_bold.svg200920-23:37:32,442 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_t1w_preproc_brain.nii.gz
# 200920-23:37:32,445 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_mean.mat
#
# 200920-23:37:32,447 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_t1w_preproc_brain.nii.gz200920-23:37:32,447 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_mean.nii.gz
#
# 200920-23:37:32,450 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/_fwhm_10/ssub-02_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-02/task-fingerfootlips/fwhm-10_ssub-02_ses-test_task-fingerfootlips_bold.nii200920-23:37:32,450 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_mean.mat
#
# 200920-23:37:32,454 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:37:32,455 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-02/task-fingerfootlips/sub-02_ses-test_task-fingerfootlips_bold_mean.nii.gz
# 200920-23:37:32,457 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_02_task_name_fingerfootlips/_fwhm_5/ssub-02_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-02/task-fingerfootlips/fwhm-5_ssub-02_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:32,461 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:37:34,340 nipype.workflow INFO:
# 	 [Job 142] Completed (preproc.datasink).
# 200920-23:37:34,343 nipype.workflow INFO:
# 	 [Job 143] Completed (preproc.datasink).
# 200920-23:37:34,349 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:34,421 nipype.workflow INFO:
# 	 [Job 154] Cached (preproc.coregwf.applywarp).
# 200920-23:37:36,344 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:36,416 nipype.workflow INFO:
# 	 [Job 155] Cached (preproc.smooth).
# 200920-23:37:36,420 nipype.workflow INFO:
# 	 [Job 156] Cached (preproc.smooth).
# 200920-23:37:36,424 nipype.workflow INFO:
# 	 [Job 157] Cached (preproc.art).
# 200920-23:37:38,346 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.
# 200920-23:37:38,426 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_01_task_name_fingerfootlips/_fwhm_10/datasink".
# 200920-23:37:38,434 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/output/workingdir/preproc/_subject_id_01_task_name_fingerfootlips/_fwhm_5/datasink".
# 200920-23:37:38,439 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200920-23:37:38,442 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold.par200920-23:37:38,443 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 200920-23:37:38,444 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/art.sub-01_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-01/task-fingerfootlips/art.sub-01_ses-test_task-fingerfootlips_bold_outliers.txt
# 200920-23:37:38,445 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_roi_mcf.nii.par -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold.par
# 200920-23:37:38,446 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/plot.sub-01_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-01/task-fingerfootlips/plot.sub-01_ses-test_task-fingerfootlips_bold.svg200920-23:37:38,447 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/art.sub-01_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt_outliers.txt -> /output/datasink/preproc/sub-01/task-fingerfootlips/art.sub-01_ses-test_task-fingerfootlips_bold_outliers.txt
#
# 200920-23:37:38,449 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/plot.sub-01_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.svg -> /output/datasink/preproc/sub-01/task-fingerfootlips/plot.sub-01_ses-test_task-fingerfootlips_bold.svg200920-23:37:38,449 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_t1w_preproc_brain.nii.gz
#
# 200920-23:37:38,451 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_t1w_preproc_brain.nii.gz -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_t1w_preproc_brain.nii.gz
# 200920-23:37:38,452 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_mean.mat
# 200920-23:37:38,452 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.mat -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_mean.mat200920-23:37:38,454 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_mean.nii.gz
#
# 200920-23:37:38,455 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/_fwhm_10/ssub-01_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-01/task-fingerfootlips/fwhm-10_ssub-01_ses-test_task-fingerfootlips_bold.nii200920-23:37:38,455 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_roi_mcf.nii_mean_reg_flirt.nii.gz -> /output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold_mean.nii.gz
#
# 200920-23:37:38,457 nipype.interface INFO:
# 	 sub: /output/datasink/preproc/_subject_id_01_task_name_fingerfootlips/_fwhm_5/ssub-01_ses-test_task-fingerfootlips_bold_roi_mcf_st_flirt.nii -> /output/datasink/preproc/sub-01/task-fingerfootlips/fwhm-5_ssub-01_ses-test_task-fingerfootlips_bold.nii
# 200920-23:37:38,459 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:37:38,463 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 200920-23:37:40,346 nipype.workflow INFO:
# 	 [Job 158] Completed (preproc.datasink).
# 200920-23:37:40,349 nipype.workflow INFO:
# 	 [Job 159] Completed (preproc.datasink).
# 200920-23:37:40,355 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 56.54/56.54, Free processors: 4/4.

# %% [markdown]
# ## Inspect output
#
# Let's check the structure of the output folder, to see if we have everything we wanted to save.

# %%
list_files('/output/datasink/preproc/sub-01/task-fingerfootlips')
# Out:
# task-fingerfootlips/
#     fwhm-10_ssub-01_ses-test_task-fingerfootlips_bold.nii
#     plot.sub-01_ses-test_task-fingerfootlips_bold.svg
#     art.sub-01_ses-test_task-fingerfootlips_bold_outliers.txt
#     sub-01_ses-test_task-fingerfootlips_bold.par
#     sub-01_ses-test_task-fingerfootlips_bold_mean.nii.gz
#     sub-01_ses-test_task-fingerfootlips_bold_mean.mat
#     sub-01_t1w_preproc_brain.nii.gz
#     fwhm-5_ssub-01_ses-test_task-fingerfootlips_bold.nii

# %% [markdown]
# ## Visualize results
#
# Let's check the effect of the different smoothing kernels.

# %%
from nilearn import image, plotting
out_path = '/output/datasink/preproc/sub-01/task-fingerfootlips'

# %%
plotting.plot_epi(opj(out_path, 'sub-01_ses-test_task-fingerfootlips_bold_mean.nii.gz'),
                  title="fwhm = 0mm", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray');

# %%
plotting.plot_epi(image.mean_img(opj(out_path, 'fwhm-5_ssub-01_ses-test_task-fingerfootlips_bold.nii')),
                  title="fwhm = 5mm", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray');

# %%
plotting.plot_epi(image.mean_img(opj(out_path, 'fwhm-10_ssub-01_ses-test_task-fingerfootlips_bold.nii')),
                  title="fwhm = 10mm", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray');

# %% [markdown]
# Now, let's investigate the motion parameters. How much did the subject move and turn in the scanner?

# %%
import numpy as np
import matplotlib.pyplot as plt
par = np.loadtxt('/output/datasink/preproc/sub-01/task-fingerfootlips/sub-01_ses-test_task-fingerfootlips_bold.par')
fig, axes = plt.subplots(2, 1, figsize=(15, 5))
axes[0].set_ylabel('rotation (radians)')
axes[0].plot(par[0:, :3])
axes[1].plot(par[0:, 3:])
axes[1].set_xlabel('time (TR)')
axes[1].set_ylabel('translation (mm)');

# %% [markdown]
# There seems to be a rather drastic motion around volume 102. Let's check if the outliers detection algorithm was able to pick this up.

# %%
import numpy as np
outlier_ids = np.loadtxt('/output/datasink/preproc/sub-01/task-fingerfootlips/art.sub-01_ses-test_task-fingerfootlips_bold_outliers.txt')
print('Outliers were detected at volumes: %s' % outlier_ids)

from IPython.display import SVG
SVG(filename='/output/datasink/preproc/sub-01/task-fingerfootlips/plot.sub-01_ses-test_task-fingerfootlips_bold.svg')
# Out:
# Outliers were detected at volumes: [ 59. 102.]

# %% [markdown]
# Alternative for motion artifacts detection [ICA-based Automatic Removal Of Motion Artifact](https://nipype.readthedocs.io/en/0.13.1/interfaces/generated/interfaces.fsl/ICA_AROMA.html)
#
#
# **Dataset:**
# [A test-retest fMRI dataset for motor, language and spatial attention functions](https://openneuro.org/datasets/ds000114/versions/1.0.1)
#
# **Special thanks to Michael Notter for the wonderful [nipype tutorial](https://miykael.github.io/nipype_tutorial/)**
