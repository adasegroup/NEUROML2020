# %% [markdown]
# # GLM: 1st-level Analysis

# %% [markdown]
# The objective in this example is to model the timecurse of each voxel. This will allow us to answer question regarding to the voxel response to different stimuli.
#
# We will model the activation at each voxel $y$ as a weighed sum of explanatory variables $x_{i}$
# and error term ${\epsilon}$
#
# $${y} = {\beta}_{0} + \sum \limits _{i=1} ^{N} x_{i}{\beta}_{i} + {\epsilon} $$
#
# or in matrix notation
#
# $$ y = {\beta} X + {\epsilon} $$
#
# which can be solved with Ordinary Least Squares regression.
#
# The paramters ${\beta}$ represnt the contribution of each variable to the voxel activation.
#
# The error terms are asumed to be independent and identically distributed.

# %% [markdown]
# ![Design matrix](https://mri-q.com/uploads/3/4/5/7/34572113/9355842_orig.jpg)

# %% [markdown]
# The matrix  𝑋  is also called design matrix.It is up to the resercher which factors to include in the design matrix. The design matirx conatins factors that a related to the hypothesis the resercher want to answer. Furthemore, sometimes in it are also included factors that are not related to the hypothesis, but are know sources of variability (nuisance factors).
#
# Now lets take a look how we take into account the delayed bold respose.
# The hemdynamic respose function might look something like this:

# %%
import numpy as np 
import matplotlib.pyplot as plt


def hrf(t):
    return t ** 8.6 * np.exp(-t / 0.547)

hrf_times = np.arange(0, 20, 0.1)
hrf_signal = hrf(hrf_times)
plt.plot(hrf_times, hrf_signal)
plt.xlabel('time')
plt.ylabel('BOLD signal')
_ = plt.title('HRF')

# %% [markdown]
# In the design Often we want to include variabales, that indicate presense or absense of a stimuli.
# Let's say we had the 3 stimly during the timecouse

# %%
n_time_points = 40

times = np.arange(0, n_time_points)  

neural_signal = np.zeros(n_time_points)
neural_signal[4:6] = 1  # A 3 second event
neural_signal[9:11] = 1
neural_signal[22:24] = 1

plt.plot(times, neural_signal)
plt.xlabel('time (seconds)')
plt.ylabel('neural signal')
plt.ylim(0, 3.2)
_ = plt.title('Neural model for three impulses')

# %% [markdown]
# Next we have to convolve signal with our hrf function

# %%
hrf_times = np.arange(20)
hrf_signal = hrf(hrf_times)
bold_signal = np.convolve(neural_signal, hrf_signal)

tailed_respose_times = np.arange(n_time_points + hrf_times.shape[0] - 1)
plt.plot(tailed_respose_times, bold_signal)
plt.xlabel('time (seconds)')
plt.ylabel('bold signal')
_ = plt.title('Convolved signals')

# %% [markdown]
# After that we can fit our fMRI data to the design Matix and use GLM to for hypotesis testing.
# We can evaluate whether a given factor $i$ has a considarable contribution by its coeficnent ${\beta}_{i}$.
# With t-test we can evaluate whether ${\beta}_{i}$ > 0. We can also test hypotesis of the form ${\beta}_{i}$ > ${\beta}_{j}$.
#
# The general form of the hypthesis tests which forms a **contrast** is:
# $$\sum \limits _{i=1} ^{N} c_{i}{\beta}_{i} > 0 $$
#
# Typical values for $c$ are 1 and -1.
# Typicaly contrasts are express as:$ [c_{1}, c_{2}, ..., c_{N}]$.
#
# For example the contrast [1, 0] tests ${\beta}_{1}$ > 0.
#
# This contrasts form a t-statisitcs (Recall that coeficents in OLS regression follow t-distribution).
#
# We can combine several contrasts and form F-statics. In the contexts of fMRI the F-tests help us answer questions like "Is effect A or effect B or effect C, or any combinaton of them, significantly non-zero?".
#
# Combining the test results from all voxels we get statistical map of brain activity.
# Now that the theory out of our way we can see how it is done in Nipype.

# %% [markdown]
# # 1st Leval Analysis in Nipype

# %% [markdown]
#  We will use the preprocessed files we got and run 1st-level analysis (individual analysis) for each subject. We will perform the following steps:
#
# 1. Extract onset times of stimuli from TVA file
# 2. Specify the model (TR, high pass filter, onset times, etc.)
# 3. Specify contrasts to compute
# 4. Estimate contrasts

# %%
import pandas as pd
import os

from nilearn import plotting
# %matplotlib inline


from nipype.interfaces.spm import Level1Design, EstimateModel, EstimateContrast
from nipype.algorithms.modelgen import SpecifySPMModel
from nipype.interfaces.utility import Function, IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype import Workflow, Node
from utils import list_files
# Out:
# 200731-13:31:32,369 nipype.utils WARNING:
# 	 A newer version (1.5.0) of nipy/nipype is available. You are using 1.5.0-rc1.post-dev

# %%
# specify paths
experiment_dir = '/output'
output_dir = 'datasink'
working_dir = 'workingdir'

# list of subject identifiers
subject_list = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10']
# Repetition time(TR) of functional images
TR = 2.5

# %% [markdown]
# ## Prepare design matrix
# Let's take a look how the stimuli onset and duration look like.This information is store in a ``tsv`` file. This file wil help us build the design matrix.
#
# The three different conditions in the **fingerfootlips** task are:
# - **finger**
# - **foot**
# - **lips**

# %%
trialinfo = pd.read_table('/data/ds000114/task-fingerfootlips_events.tsv')
trialinfo.head()
# Out:
#    onset  duration  weight trial_type
# 0     10      15.0       1     Finger
# 1     40      15.0       1       Foot
# 2     70      15.0       1       Lips
# 3    100      15.0       1     Finger
# 4    130      15.0       1       Foot

# %%
def subjectinfo(subject_id):
    import pandas as pd
    from nipype.interfaces.base import Bunch

    
    trialinfo = pd.read_table('/data/ds000114/task-fingerfootlips_events.tsv')
    trialinfo.head()
    conditions = []
    onsets = []
    durations = []

    for group in trialinfo.groupby('trial_type'):
        conditions.append(group[0])
        onsets.append(list(group[1].onset - 10)) # subtracting 10s due to removing of 4 dummy scans
        durations.append(group[1].duration.tolist())

    subject_info = [Bunch(conditions=conditions,
                          onsets=onsets,
                          durations=durations
                         )]

    return subject_info  # this output will later be returned to infosource

# Get Subject Info - get subject specific condition information
getsubjectinfo = Node(Function(input_names=['subject_id'],
                               output_names=['subject_info'],
                               function=subjectinfo),
                      name='getsubjectinfo')

# %% [markdown]
# ## Initiate Nodes

# %%
# SpecifyModel - Generates SPM-specific Model
#Setup
#https://nipype.readthedocs.io/en/latest/api/generated/nipype.algorithms.modelgen.html#specifymodel
modelspec = Node(SpecifySPMModel(concatenate_runs=False,
                                 input_units='secs',
                                 output_units='secs',
                                 time_repetition=TR,
                                 high_pass_filter_cutoff=128),
                 name="modelspec")

# Level1Design - Generates an SPM design matrix
#https://www.fil.ion.ucl.ac.uk/spm/doc/manual.pdf#page=59
#hrf- Name of basis function(canonical)
#'derivs': [1, 0]-Time derivatives : Time and Dispersion

#model_serial_correlations-serial correlations using an autoregressive estimator (order 1)

level1design = Node(Level1Design(bases={'hrf': {'derivs': [1, 0]}},
                                 timing_units='secs',
                                 interscan_interval=TR,
                                 model_serial_correlations='AR(1)'),
                    name="level1design")

# EstimateModel - estimate the parameters of the model
#https://www.fil.ion.ucl.ac.uk/spm/doc/manual.pdf#page=69

level1estimate = Node(EstimateModel(estimation_method={'Classical': 1}),
                      name="level1estimate")

# EstimateContrast - estimates contrasts
level1conest = Node(EstimateContrast(), name="level1conest")

# %% [markdown]
# ## Specify contrasts
# We are gona perform several T tests and one F test. Recall the general form of the hypothesis are
#
# $$\sum \limits _{i=1} ^{N} c_{i}{\beta}_{i} > 0 $$

# %%
# Condition names
condition_names = ['Finger', 'Foot', 'Lips']

# Contrasts
# contrast =  [<contrast_name>, <test>, <condition_names>, <[c1, c2, c3]>]
cont01 = ['average',        'T', condition_names, [1/3., 1/3., 1/3.]]
cont02 = ['Finger',         'T', condition_names, [1, 0, 0]]
cont03 = ['Foot',           'T', condition_names, [0, 1, 0]]
cont04 = ['Lips',           'T', condition_names, [0, 0, 1]]
cont05 = ['Foot > others',  'T', condition_names, [-0.5, 1, -0.5]]
cont06 = ['activation',     'F', [cont02, cont03, cont04]]
# fill a contrast 'Finger > others'
contrast_list = [cont01, cont02, cont03, cont04, cont05, cont06]

# %% [markdown]
# ## Specify input & output stream
#
# Specify where the input data can be found & where and how to save the output data.

# %%
#Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id',
                                            'contrasts'],
                                    contrasts=contrast_list),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
templates = {
        'func': 'datasink/preproc/sub-{subject_id}/task-{task_id}/ssub-{subject_id}_ses-test_task-{task_id}_bold.nii',
        'mc_param': 'datasink/preproc/sub-{subject_id}/task-{task_id}/sub-{subject_id}_ses-test_task-{task_id}_bold.par',
        'outliers': 'datasink/preproc/sub-{subject_id}/task-{task_id}/art.sub-{subject_id}_ses-test_task-{task_id}_bold_outliers.txt'
    }
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")
selectfiles.inputs.task_id = 'fingerfootlips'

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
substitutions = [('_subject_id_', 'sub-')]
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ## Specify Workflow
#
# Create a workflow and **connect** the interface nodes and the I/O stream to each other.

# %%
# Initiation of the 1st-level analysis workflow
l1analysis = Workflow(name='l1analysis')
l1analysis.base_dir = f'{experiment_dir}/{working_dir}'

# Connect up the 1st-level analysis components
l1analysis.connect([(infosource, selectfiles, [('subject_id', 'subject_id')]),
                    (infosource, getsubjectinfo, [('subject_id',
                                                   'subject_id')]),
                    (getsubjectinfo, modelspec, [('subject_info',
                                                  'subject_info')]),
                    (infosource, level1conest, [('contrasts', 'contrasts')]),
                    (selectfiles, modelspec, [('func', 'functional_runs')]),
                    (selectfiles, modelspec, [('mc_param', 'realignment_parameters'),
                                              ('outliers', 'outlier_files')]),
                    (modelspec, level1design, [('session_info',
                                                'session_info')]),
                    (level1design, level1estimate, [('spm_mat_file',
                                                     'spm_mat_file')]),
                    (level1estimate, level1conest, [('spm_mat_file',
                                                     'spm_mat_file'),
                                                    ('beta_images',
                                                     'beta_images'),
                                                    ('residual_image',
                                                     'residual_image')]),
                    (level1conest, datasink, [('spm_mat_file', '1stLevel.@spm_mat'),
                                              ('spmT_images', '1stLevel.@T'),
                                              ('con_images', '1stLevel.@con'),
                                              ('spmF_images', '1stLevel.@F'),
                                              ('ess_images', '1stLevel.@ess'),
                                              ]),
                    ])

# %% [markdown]
# ## Visualize the workflow

# %%
# Save the 1st-level analysis graph as png
l1analysis.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=f'{l1analysis.base_dir}/l1analysis/graph.png')
# Out:
# 200731-13:31:32,978 nipype.workflow INFO:
# 	 Generated workflow graph: /output/workingdir/l1analysis/graph.png (graph2use=colored, simple_form=True).

# %%
# show detailed workflow
l1analysis.write_graph(graph2use='flat', format='png', simple_form=True)
Image(filename=f'{l1analysis.base_dir}/l1analysis/graph_detailed.png')
# Out:
# 200731-13:31:33,539 nipype.workflow INFO:
# 	 Generated workflow graph: /output/workingdir/l1analysis/graph.png (graph2use=flat, simple_form=True).

# %% [markdown]
# ##  Run the Workflow
#
# Run the 1st-level analysis workflow.

# %%
l1analysis.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 200731-13:31:33,588 nipype.workflow INFO:
# 	 Workflow l1analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 200731-13:31:33,658 nipype.workflow INFO:
# 	 Running in parallel.
# 200731-13:31:33,665 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 20 jobs ready. Free memory (GB): 226.64/226.64, Free processors: 4/4.
# 200731-13:31:33,752 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_09/getsubjectinfo".200731-13:31:33,752 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_10/selectfiles".
#
# 200731-13:31:33,763 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")200731-13:31:33,764 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 200731-13:31:33,750 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_10/getsubjectinfo".
# 200731-13:31:33,772 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:31:33,778 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
# 200731-13:31:33,784 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 200731-13:31:33,800 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".200731-13:31:33,752 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_09/selectfiles".
#
# 200731-13:31:33,811 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200731-13:31:33,819 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:31:35,665 nipype.workflow INFO:
# 	 [Job 0] Completed (l1analysis.getsubjectinfo).
# 200731-13:31:35,667 nipype.workflow INFO:
# 	 [Job 1] Completed (l1analysis.selectfiles).
# 200731-13:31:35,669 nipype.workflow INFO:
# 	 [Job 7] Completed (l1analysis.getsubjectinfo).
# 200731-13:31:35,671 nipype.workflow INFO:
# 	 [Job 8] Completed (l1analysis.selectfiles).
# 200731-13:31:35,674 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 18 jobs ready. Free memory (GB): 226.64/226.64, Free processors: 4/4.
# 200731-13:31:35,733 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_10/modelspec".200731-13:31:35,734 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_09/modelspec".
# 200731-13:31:35,734 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_08/getsubjectinfo".200731-13:31:35,735 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_08/selectfiles".
#
#
# 200731-13:31:35,740 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")200731-13:31:35,742 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 200731-13:31:35,747 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")200731-13:31:35,747 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
#
# 200731-13:31:35,750 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:31:35,756 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 200731-13:31:35,772 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".200731-13:31:35,772 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
#
# 200731-13:31:37,667 nipype.workflow INFO:
# 	 [Job 2] Completed (l1analysis.modelspec).
# 200731-13:31:37,670 nipype.workflow INFO:
# 	 [Job 9] Completed (l1analysis.modelspec).
# 200731-13:31:37,673 nipype.workflow INFO:
# 	 [Job 14] Completed (l1analysis.getsubjectinfo).
# 200731-13:31:37,676 nipype.workflow INFO:
# 	 [Job 15] Completed (l1analysis.selectfiles).
# 200731-13:31:37,680 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 17 jobs ready. Free memory (GB): 226.64/226.64, Free processors: 4/4.
# 200731-13:31:37,752 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_10/level1design".
# 200731-13:31:37,754 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_08/modelspec".200731-13:31:37,754 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_07/getsubjectinfo".200731-13:31:37,753 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_09/level1design".
#
#
# 200731-13:31:37,760 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
# 200731-13:31:37,768 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 200731-13:31:37,782 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 200731-13:31:37,791 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 200731-13:31:37,804 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:31:37,807 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:31:39,670 nipype.workflow INFO:
# 	 [Job 16] Completed (l1analysis.modelspec).
# 200731-13:31:39,672 nipype.workflow INFO:
# 	 [Job 21] Completed (l1analysis.getsubjectinfo).
# 200731-13:31:39,677 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 14 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:31:39,738 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_08/level1design".200731-13:31:39,739 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_07/selectfiles".
#
# 200731-13:31:39,745 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200731-13:31:39,752 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:31:39,788 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:31:41,672 nipype.workflow INFO:
# 	 [Job 22] Completed (l1analysis.selectfiles).
# 200731-13:31:41,677 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 13 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:31:41,743 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_07/modelspec".
# 200731-13:31:41,756 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 200731-13:31:41,779 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 200731-13:31:43,674 nipype.workflow INFO:
# 	 [Job 23] Completed (l1analysis.modelspec).
# 200731-13:31:43,679 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 13 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:31:43,741 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_07/level1design".
# 200731-13:31:43,791 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:31:45,677 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 12 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:31:48,497 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:31:48,501 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:31:49,679 nipype.workflow INFO:
# 	 [Job 3] Completed (l1analysis.level1design).
# 200731-13:31:49,681 nipype.workflow INFO:
# 	 [Job 10] Completed (l1analysis.level1design).
# 200731-13:31:49,685 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 14 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:31:49,744 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_10/level1estimate".200731-13:31:49,744 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_09/level1estimate".
#
# 200731-13:31:49,755 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")200731-13:31:49,755 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
#
# 200731-13:31:50,473 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:31:51,682 nipype.workflow INFO:
# 	 [Job 17] Completed (l1analysis.level1design).
# 200731-13:31:51,687 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 13 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 200731-13:31:51,750 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_08/level1estimate".
# 200731-13:31:51,762 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:31:53,686 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 12 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 200731-13:31:54,500 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:31:55,686 nipype.workflow INFO:
# 	 [Job 24] Completed (l1analysis.level1design).
# 200731-13:31:55,691 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 13 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:31:55,757 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_07/level1estimate".
# 200731-13:31:55,766 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:31:57,690 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 12 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:32:02,303 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:02,482 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:03,694 nipype.workflow INFO:
# 	 [Job 4] Completed (l1analysis.level1estimate).
# 200731-13:32:03,697 nipype.workflow INFO:
# 	 [Job 11] Completed (l1analysis.level1estimate).
# 200731-13:32:03,702 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 14 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:32:03,770 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_10/level1conest".200731-13:32:03,770 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_09/level1conest".
#
# 200731-13:32:03,791 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:03,793 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:04,568 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:05,696 nipype.workflow INFO:
# 	 [Job 18] Completed (l1analysis.level1estimate).
# 200731-13:32:05,701 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 13 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1estimate
# 200731-13:32:05,767 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_08/level1conest".
# 200731-13:32:05,787 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:07,700 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 12 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1estimate
# 200731-13:32:08,248 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:09,700 nipype.workflow INFO:
# 	 [Job 25] Completed (l1analysis.level1estimate).
# 200731-13:32:09,705 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 13 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 200731-13:32:09,768 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_07/level1conest".
# 200731-13:32:09,792 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:11,704 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 12 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 200731-13:32:13,28 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:32:13,209 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:32:13,704 nipype.workflow INFO:
# 	 [Job 5] Completed (l1analysis.level1conest).
# 200731-13:32:13,708 nipype.workflow INFO:
# 	 [Job 12] Completed (l1analysis.level1conest).
# 200731-13:32:13,712 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 14 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 200731-13:32:13,775 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_09/datasink".200731-13:32:13,775 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_10/datasink".
#
# 200731-13:32:13,786 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200731-13:32:13,788 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/SPM.mat -> /output/datasink/1stLevel/sub-09/SPM.mat200731-13:32:13,789 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 200731-13:32:13,790 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/spmT_0001.nii -> /output/datasink/1stLevel/sub-09/spmT_0001.nii
# 200731-13:32:13,791 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/SPM.mat -> /output/datasink/1stLevel/sub-10/SPM.mat200731-13:32:13,792 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/spmT_0002.nii -> /output/datasink/1stLevel/sub-09/spmT_0002.nii
#
# 200731-13:32:13,793 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/spmT_0001.nii -> /output/datasink/1stLevel/sub-10/spmT_0001.nii200731-13:32:13,794 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/spmT_0003.nii -> /output/datasink/1stLevel/sub-09/spmT_0003.nii
#
# 200731-13:32:13,795 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/spmT_0002.nii -> /output/datasink/1stLevel/sub-10/spmT_0002.nii200731-13:32:13,796 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/spmT_0004.nii -> /output/datasink/1stLevel/sub-09/spmT_0004.nii
#
# 200731-13:32:13,797 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/spmT_0003.nii -> /output/datasink/1stLevel/sub-10/spmT_0003.nii200731-13:32:13,797 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/spmT_0005.nii -> /output/datasink/1stLevel/sub-09/spmT_0005.nii
#
# 200731-13:32:13,799 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/spmT_0004.nii -> /output/datasink/1stLevel/sub-10/spmT_0004.nii200731-13:32:13,799 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/spmF_0006.nii -> /output/datasink/1stLevel/sub-09/spmF_0006.nii
#
# 200731-13:32:13,800 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/spmT_0005.nii -> /output/datasink/1stLevel/sub-10/spmT_0005.nii200731-13:32:13,801 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/con_0001.nii -> /output/datasink/1stLevel/sub-09/con_0001.nii
#
# 200731-13:32:13,802 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/spmF_0006.nii -> /output/datasink/1stLevel/sub-10/spmF_0006.nii200731-13:32:13,803 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/con_0002.nii -> /output/datasink/1stLevel/sub-09/con_0002.nii
#
# 200731-13:32:13,804 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/con_0001.nii -> /output/datasink/1stLevel/sub-10/con_0001.nii200731-13:32:13,805 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/con_0003.nii -> /output/datasink/1stLevel/sub-09/con_0003.nii
#
# 200731-13:32:13,806 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/con_0002.nii -> /output/datasink/1stLevel/sub-10/con_0002.nii200731-13:32:13,807 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/con_0004.nii -> /output/datasink/1stLevel/sub-09/con_0004.nii
#
# 200731-13:32:13,808 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/con_0003.nii -> /output/datasink/1stLevel/sub-10/con_0003.nii
# 200731-13:32:13,809 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/con_0005.nii -> /output/datasink/1stLevel/sub-09/con_0005.nii200731-13:32:13,809 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/con_0004.nii -> /output/datasink/1stLevel/sub-10/con_0004.nii
#
# 200731-13:32:13,810 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/ess_0006.nii -> /output/datasink/1stLevel/sub-09/ess_0006.nii200731-13:32:13,811 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/con_0005.nii -> /output/datasink/1stLevel/sub-10/con_0005.nii
#
# 200731-13:32:13,812 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/spmF_0006.nii -> /output/datasink/1stLevel/sub-09/spmF_0006.nii200731-13:32:13,812 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/ess_0006.nii -> /output/datasink/1stLevel/sub-10/ess_0006.nii
#
# 200731-13:32:13,814 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/spmF_0006.nii -> /output/datasink/1stLevel/sub-10/spmF_0006.nii200731-13:32:13,814 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_09/ess_0006.nii -> /output/datasink/1stLevel/sub-09/ess_0006.nii
# 200731-13:32:13,816 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_10/ess_0006.nii -> /output/datasink/1stLevel/sub-10/ess_0006.nii
#
# 200731-13:32:13,820 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:32:13,821 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:32:15,113 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:32:15,706 nipype.workflow INFO:
# 	 [Job 19] Completed (l1analysis.level1conest).
# 200731-13:32:15,710 nipype.workflow INFO:
# 	 [Job 6] Completed (l1analysis.datasink).
# 200731-13:32:15,712 nipype.workflow INFO:
# 	 [Job 13] Completed (l1analysis.datasink).
# 200731-13:32:15,716 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 13 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 200731-13:32:15,776 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_08/datasink".200731-13:32:15,777 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_06/getsubjectinfo".200731-13:32:15,777 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_06/selectfiles".
#
#
# 200731-13:32:15,782 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")200731-13:32:15,783 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 200731-13:32:15,789 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:32:15,791 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200731-13:32:15,794 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/SPM.mat -> /output/datasink/1stLevel/sub-08/SPM.mat
# 200731-13:32:15,796 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/spmT_0001.nii -> /output/datasink/1stLevel/sub-08/spmT_0001.nii
# 200731-13:32:15,798 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/spmT_0002.nii -> /output/datasink/1stLevel/sub-08/spmT_0002.nii
# 200731-13:32:15,800 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/spmT_0003.nii -> /output/datasink/1stLevel/sub-08/spmT_0003.nii200731-13:32:15,800 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
#
# 200731-13:32:15,802 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/spmT_0004.nii -> /output/datasink/1stLevel/sub-08/spmT_0004.nii
# 200731-13:32:15,804 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/spmT_0005.nii -> /output/datasink/1stLevel/sub-08/spmT_0005.nii
# 200731-13:32:15,806 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/spmF_0006.nii -> /output/datasink/1stLevel/sub-08/spmF_0006.nii
# 200731-13:32:15,808 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/con_0001.nii -> /output/datasink/1stLevel/sub-08/con_0001.nii
# 200731-13:32:15,810 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/con_0002.nii -> /output/datasink/1stLevel/sub-08/con_0002.nii
# 200731-13:32:15,812 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/con_0003.nii -> /output/datasink/1stLevel/sub-08/con_0003.nii
# 200731-13:32:15,814 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/con_0004.nii -> /output/datasink/1stLevel/sub-08/con_0004.nii
# 200731-13:32:15,816 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/con_0005.nii -> /output/datasink/1stLevel/sub-08/con_0005.nii
# 200731-13:32:15,818 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/ess_0006.nii -> /output/datasink/1stLevel/sub-08/ess_0006.nii
# 200731-13:32:15,820 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/spmF_0006.nii -> /output/datasink/1stLevel/sub-08/spmF_0006.nii
# 200731-13:32:15,822 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_08/ess_0006.nii -> /output/datasink/1stLevel/sub-08/ess_0006.nii
# 200731-13:32:15,827 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:32:17,709 nipype.workflow INFO:
# 	 [Job 20] Completed (l1analysis.datasink).
# 200731-13:32:17,712 nipype.workflow INFO:
# 	 [Job 28] Completed (l1analysis.getsubjectinfo).
# 200731-13:32:17,714 nipype.workflow INFO:
# 	 [Job 29] Completed (l1analysis.selectfiles).
# 200731-13:32:17,719 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 11 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 200731-13:32:17,780 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_06/modelspec".200731-13:32:17,780 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_05/getsubjectinfo".
# 200731-13:32:17,781 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_05/selectfiles".
#
# 200731-13:32:17,786 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
# 200731-13:32:17,788 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200731-13:32:17,793 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 200731-13:32:17,796 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:32:17,801 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 200731-13:32:17,818 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 200731-13:32:19,85 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:32:19,711 nipype.workflow INFO:
# 	 [Job 26] Completed (l1analysis.level1conest).
# 200731-13:32:19,714 nipype.workflow INFO:
# 	 [Job 30] Completed (l1analysis.modelspec).
# 200731-13:32:19,718 nipype.workflow INFO:
# 	 [Job 35] Completed (l1analysis.getsubjectinfo).
# 200731-13:32:19,720 nipype.workflow INFO:
# 	 [Job 36] Completed (l1analysis.selectfiles).
# 200731-13:32:19,724 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 226.64/226.64, Free processors: 4/4.
# 200731-13:32:19,795 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_07/datasink".
# 200731-13:32:19,796 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_06/level1design".200731-13:32:19,796 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_04/getsubjectinfo".200731-13:32:19,796 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_05/modelspec".
#
#
# 200731-13:32:19,802 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
# 200731-13:32:19,809 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200731-13:32:19,810 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 200731-13:32:19,812 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/SPM.mat -> /output/datasink/1stLevel/sub-07/SPM.mat
# 200731-13:32:19,814 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/spmT_0001.nii -> /output/datasink/1stLevel/sub-07/spmT_0001.nii
# 200731-13:32:19,816 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".200731-13:32:19,816 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/spmT_0002.nii -> /output/datasink/1stLevel/sub-07/spmT_0002.nii
#
# 200731-13:32:19,818 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/spmT_0003.nii -> /output/datasink/1stLevel/sub-07/spmT_0003.nii
# 200731-13:32:19,820 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/spmT_0004.nii -> /output/datasink/1stLevel/sub-07/spmT_0004.nii
# 200731-13:32:19,822 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/spmT_0005.nii -> /output/datasink/1stLevel/sub-07/spmT_0005.nii
# 200731-13:32:19,824 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/spmF_0006.nii -> /output/datasink/1stLevel/sub-07/spmF_0006.nii
# 200731-13:32:19,826 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/con_0001.nii -> /output/datasink/1stLevel/sub-07/con_0001.nii
# 200731-13:32:19,828 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/con_0002.nii -> /output/datasink/1stLevel/sub-07/con_0002.nii
# 200731-13:32:19,830 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/con_0003.nii -> /output/datasink/1stLevel/sub-07/con_0003.nii
# 200731-13:32:19,833 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/con_0004.nii -> /output/datasink/1stLevel/sub-07/con_0004.nii
# 200731-13:32:19,835 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/con_0005.nii -> /output/datasink/1stLevel/sub-07/con_0005.nii
# 200731-13:32:19,836 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 200731-13:32:19,837 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/ess_0006.nii -> /output/datasink/1stLevel/sub-07/ess_0006.nii
# 200731-13:32:19,839 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/spmF_0006.nii -> /output/datasink/1stLevel/sub-07/spmF_0006.nii
# 200731-13:32:19,841 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_07/ess_0006.nii -> /output/datasink/1stLevel/sub-07/ess_0006.nii
# 200731-13:32:19,845 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:32:19,850 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:32:21,713 nipype.workflow INFO:
# 	 [Job 27] Completed (l1analysis.datasink).
# 200731-13:32:21,716 nipype.workflow INFO:
# 	 [Job 37] Completed (l1analysis.modelspec).
# 200731-13:32:21,719 nipype.workflow INFO:
# 	 [Job 42] Completed (l1analysis.getsubjectinfo).
# 200731-13:32:21,723 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 8 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1design
# 200731-13:32:21,784 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_05/level1design".200731-13:32:21,785 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_03/getsubjectinfo".200731-13:32:21,784 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_04/selectfiles".
#
#
# 200731-13:32:21,791 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")200731-13:32:21,791 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 200731-13:32:21,799 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:32:21,807 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 200731-13:32:21,838 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:32:23,715 nipype.workflow INFO:
# 	 [Job 43] Completed (l1analysis.selectfiles).
# 200731-13:32:23,718 nipype.workflow INFO:
# 	 [Job 49] Completed (l1analysis.getsubjectinfo).
# 200731-13:32:23,722 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:32:23,784 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_04/modelspec".200731-13:32:23,784 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/output/workingdir/l1analysis/_subject_id_03/selectfiles".
#
# 200731-13:32:23,791 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200731-13:32:23,796 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 200731-13:32:23,799 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 200731-13:32:23,821 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 200731-13:32:25,717 nipype.workflow INFO:
# 	 [Job 44] Completed (l1analysis.modelspec).
# 200731-13:32:25,720 nipype.workflow INFO:
# 	 [Job 50] Completed (l1analysis.selectfiles).
# 200731-13:32:25,724 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:32:25,785 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_04/level1design".200731-13:32:25,785 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_03/modelspec".
#
# 200731-13:32:25,798 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 200731-13:32:25,823 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 200731-13:32:25,840 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:32:27,718 nipype.workflow INFO:
# 	 [Job 51] Completed (l1analysis.modelspec).
# 200731-13:32:27,723 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:32:27,804 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_03/level1design".
# 200731-13:32:27,860 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:32:28,642 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:32:29,721 nipype.workflow INFO:
# 	 [Job 31] Completed (l1analysis.level1design).
# 200731-13:32:29,725 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:32:29,808 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_06/level1estimate".
# 200731-13:32:29,819 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:32:30,724 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:32:31,723 nipype.workflow INFO:
# 	 [Job 38] Completed (l1analysis.level1design).
# 200731-13:32:31,727 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:32:31,806 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_05/level1estimate".
# 200731-13:32:31,818 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:32:33,726 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 4 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:32:34,746 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:32:35,726 nipype.workflow INFO:
# 	 [Job 45] Completed (l1analysis.level1design).
# 200731-13:32:35,731 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 200731-13:32:35,791 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_04/level1estimate".
# 200731-13:32:35,802 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:32:36,783 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:32:37,729 nipype.workflow INFO:
# 	 [Job 52] Completed (l1analysis.level1design).
# 200731-13:32:37,734 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:32:37,794 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_03/level1estimate".
# 200731-13:32:37,803 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:32:39,732 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 4 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:32:42,691 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:43,733 nipype.workflow INFO:
# 	 [Job 32] Completed (l1analysis.level1estimate).
# 200731-13:32:43,738 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:32:43,809 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_06/level1conest".
# 200731-13:32:43,833 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:44,930 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:45,735 nipype.workflow INFO:
# 	 [Job 39] Completed (l1analysis.level1estimate).
# 200731-13:32:45,740 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:32:45,817 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_05/level1conest".
# 200731-13:32:45,839 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:47,739 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 4 jobs ready. Free memory (GB): 225.84/226.64, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:32:48,697 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:49,739 nipype.workflow INFO:
# 	 [Job 46] Completed (l1analysis.level1estimate).
# 200731-13:32:49,744 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1estimate
# 200731-13:32:49,810 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_04/level1conest".
# 200731-13:32:49,833 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:50,315 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:32:51,741 nipype.workflow INFO:
# 	 [Job 53] Completed (l1analysis.level1estimate).
# 200731-13:32:51,745 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 200731-13:32:51,809 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_03/level1conest".
# 200731-13:32:51,831 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:32:53,327 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:32:53,743 nipype.workflow INFO:
# 	 [Job 33] Completed (l1analysis.level1conest).
# 200731-13:32:53,748 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 5 jobs ready. Free memory (GB): 226.04/226.64, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 200731-13:32:53,812 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_06/datasink".
# 200731-13:32:53,825 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200731-13:32:53,828 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/SPM.mat -> /output/datasink/1stLevel/sub-06/SPM.mat
# 200731-13:32:53,830 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/spmT_0001.nii -> /output/datasink/1stLevel/sub-06/spmT_0001.nii
# 200731-13:32:53,832 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/spmT_0002.nii -> /output/datasink/1stLevel/sub-06/spmT_0002.nii
# 200731-13:32:53,834 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/spmT_0003.nii -> /output/datasink/1stLevel/sub-06/spmT_0003.nii
# 200731-13:32:53,836 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/spmT_0004.nii -> /output/datasink/1stLevel/sub-06/spmT_0004.nii
# 200731-13:32:53,838 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/spmT_0005.nii -> /output/datasink/1stLevel/sub-06/spmT_0005.nii
# 200731-13:32:53,840 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/spmF_0006.nii -> /output/datasink/1stLevel/sub-06/spmF_0006.nii
# 200731-13:32:53,842 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/con_0001.nii -> /output/datasink/1stLevel/sub-06/con_0001.nii
# 200731-13:32:53,844 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/con_0002.nii -> /output/datasink/1stLevel/sub-06/con_0002.nii
# 200731-13:32:53,846 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/con_0003.nii -> /output/datasink/1stLevel/sub-06/con_0003.nii
# 200731-13:32:53,847 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/con_0004.nii -> /output/datasink/1stLevel/sub-06/con_0004.nii
# 200731-13:32:53,849 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/con_0005.nii -> /output/datasink/1stLevel/sub-06/con_0005.nii
# 200731-13:32:53,851 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/ess_0006.nii -> /output/datasink/1stLevel/sub-06/ess_0006.nii
# 200731-13:32:53,853 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/spmF_0006.nii -> /output/datasink/1stLevel/sub-06/spmF_0006.nii
# 200731-13:32:53,855 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_06/ess_0006.nii -> /output/datasink/1stLevel/sub-06/ess_0006.nii
# 200731-13:32:53,860 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:32:55,128 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:32:55,745 nipype.workflow INFO:
# 	 [Job 40] Completed (l1analysis.level1conest).
# 200731-13:32:55,748 nipype.workflow INFO:
# 	 [Job 34] Completed (l1analysis.datasink).
# 200731-13:32:55,753 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 200731-13:32:55,815 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_05/datasink".200731-13:32:55,815 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/output/workingdir/l1analysis/_subject_id_02/getsubjectinfo".
#
# 200731-13:32:55,821 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
# 200731-13:32:55,829 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200731-13:32:55,831 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_05/SPM.mat -> /output/datasink/1stLevel/sub-05/SPM.mat
# 200731-13:32:55,834 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_05/spmT_0001.nii -> /output/datasink/1stLevel/sub-05/spmT_0001.nii
# 200731-13:32:55,836 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_05/spmT_0002.nii -> /output/datasink/1stLevel/sub-05/spmT_0002.nii
# 200731-13:32:55,837 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".200731-13:32:55,837 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_05/spmT_0003.nii -> /output/datasink/1stLevel/sub-05/spmT_0003.nii
#
# 200731-13:32:55,839 nipype.interface INFO:
# ...
# 200731-13:32:59,847 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/spmF_0006.nii -> /output/datasink/1stLevel/sub-04/spmF_0006.nii
# 200731-13:32:59,849 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 200731-13:32:59,849 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/con_0001.nii -> /output/datasink/1stLevel/sub-04/con_0001.nii
# 200731-13:32:59,851 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/con_0002.nii -> /output/datasink/1stLevel/sub-04/con_0002.nii
# 200731-13:32:59,853 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/con_0003.nii -> /output/datasink/1stLevel/sub-04/con_0003.nii
# 200731-13:32:59,855 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/con_0004.nii -> /output/datasink/1stLevel/sub-04/con_0004.nii
# 200731-13:32:59,857 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/con_0005.nii -> /output/datasink/1stLevel/sub-04/con_0005.nii
# 200731-13:32:59,859 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/ess_0006.nii -> /output/datasink/1stLevel/sub-04/ess_0006.nii
# 200731-13:32:59,861 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/spmF_0006.nii -> /output/datasink/1stLevel/sub-04/spmF_0006.nii
# 200731-13:32:59,863 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_04/ess_0006.nii -> /output/datasink/1stLevel/sub-04/ess_0006.nii
# 200731-13:32:59,868 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:33:01,114 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:33:01,751 nipype.workflow INFO:
# 	 [Job 54] Completed (l1analysis.level1conest).
# 200731-13:33:01,755 nipype.workflow INFO:
# 	 [Job 48] Completed (l1analysis.datasink).
# 200731-13:33:01,758 nipype.workflow INFO:
# 	 [Job 58] Completed (l1analysis.modelspec).
# 200731-13:33:01,761 nipype.workflow INFO:
# 	 [Job 64] Completed (l1analysis.selectfiles).
# 200731-13:33:01,765 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 226.64/226.64, Free processors: 4/4.
# 200731-13:33:01,836 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_03/datasink".200731-13:33:01,837 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_02/level1design".200731-13:33:01,837 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/output/workingdir/l1analysis/_subject_id_01/modelspec".
#
#
# 200731-13:33:01,851 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")200731-13:33:01,851 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 200731-13:33:01,854 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/SPM.mat -> /output/datasink/1stLevel/sub-03/SPM.mat
# 200731-13:33:01,856 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/spmT_0001.nii -> /output/datasink/1stLevel/sub-03/spmT_0001.nii
# 200731-13:33:01,859 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/spmT_0002.nii -> /output/datasink/1stLevel/sub-03/spmT_0002.nii
# 200731-13:33:01,861 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/spmT_0003.nii -> /output/datasink/1stLevel/sub-03/spmT_0003.nii
# 200731-13:33:01,863 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/spmT_0004.nii -> /output/datasink/1stLevel/sub-03/spmT_0004.nii
# 200731-13:33:01,865 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/spmT_0005.nii -> /output/datasink/1stLevel/sub-03/spmT_0005.nii
# 200731-13:33:01,867 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/spmF_0006.nii -> /output/datasink/1stLevel/sub-03/spmF_0006.nii
# 200731-13:33:01,869 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/con_0001.nii -> /output/datasink/1stLevel/sub-03/con_0001.nii
# 200731-13:33:01,871 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/con_0002.nii -> /output/datasink/1stLevel/sub-03/con_0002.nii
# 200731-13:33:01,873 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/con_0003.nii -> /output/datasink/1stLevel/sub-03/con_0003.nii
# 200731-13:33:01,875 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/con_0004.nii -> /output/datasink/1stLevel/sub-03/con_0004.nii
# 200731-13:33:01,877 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/con_0005.nii -> /output/datasink/1stLevel/sub-03/con_0005.nii
# 200731-13:33:01,879 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/ess_0006.nii -> /output/datasink/1stLevel/sub-03/ess_0006.nii
# 200731-13:33:01,880 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".200731-13:33:01,881 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/spmF_0006.nii -> /output/datasink/1stLevel/sub-03/spmF_0006.nii200731-13:33:01,881 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
#
#
# 200731-13:33:01,883 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_03/ess_0006.nii -> /output/datasink/1stLevel/sub-03/ess_0006.nii
# 200731-13:33:01,888 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:33:03,753 nipype.workflow INFO:
# 	 [Job 55] Completed (l1analysis.datasink).
# 200731-13:33:03,756 nipype.workflow INFO:
# 	 [Job 65] Completed (l1analysis.modelspec).
# 200731-13:33:03,761 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1design
# 200731-13:33:03,822 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/output/workingdir/l1analysis/_subject_id_01/level1design".
# 200731-13:33:03,888 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 200731-13:33:05,756 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 200731-13:33:10,806 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:33:11,761 nipype.workflow INFO:
# 	 [Job 59] Completed (l1analysis.level1design).
# 200731-13:33:11,766 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1design
# 200731-13:33:11,827 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_02/level1estimate".
# 200731-13:33:11,839 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:33:12,898 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 200731-13:33:13,763 nipype.workflow INFO:
# 	 [Job 66] Completed (l1analysis.level1design).
# 200731-13:33:13,767 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1estimate
# 200731-13:33:13,828 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/output/workingdir/l1analysis/_subject_id_01/level1estimate".
# 200731-13:33:13,837 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 200731-13:33:15,766 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 200731-13:33:24,725 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:33:25,775 nipype.workflow INFO:
# 	 [Job 60] Completed (l1analysis.level1estimate).
# 200731-13:33:25,780 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1estimate
# 200731-13:33:25,843 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_02/level1conest".
# 200731-13:33:25,860 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:33:26,164 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 200731-13:33:27,777 nipype.workflow INFO:
# 	 [Job 67] Completed (l1analysis.level1estimate).
# 200731-13:33:27,782 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 200731-13:33:27,845 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/output/workingdir/l1analysis/_subject_id_01/level1conest".
# 200731-13:33:27,866 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 200731-13:33:29,781 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 226.24/226.64, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 200731-13:33:35,27 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:33:35,785 nipype.workflow INFO:
# 	 [Job 61] Completed (l1analysis.level1conest).
# 200731-13:33:35,790 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 226.44/226.64, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 200731-13:33:35,848 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_02/datasink".
# 200731-13:33:35,858 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200731-13:33:35,860 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/SPM.mat -> /output/datasink/1stLevel/sub-02/SPM.mat
# 200731-13:33:35,862 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/spmT_0001.nii -> /output/datasink/1stLevel/sub-02/spmT_0001.nii
# 200731-13:33:35,864 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/spmT_0002.nii -> /output/datasink/1stLevel/sub-02/spmT_0002.nii
# 200731-13:33:35,866 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/spmT_0003.nii -> /output/datasink/1stLevel/sub-02/spmT_0003.nii
# 200731-13:33:35,868 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/spmT_0004.nii -> /output/datasink/1stLevel/sub-02/spmT_0004.nii
# 200731-13:33:35,870 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/spmT_0005.nii -> /output/datasink/1stLevel/sub-02/spmT_0005.nii
# 200731-13:33:35,872 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/spmF_0006.nii -> /output/datasink/1stLevel/sub-02/spmF_0006.nii
# 200731-13:33:35,873 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/con_0001.nii -> /output/datasink/1stLevel/sub-02/con_0001.nii
# 200731-13:33:35,875 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/con_0002.nii -> /output/datasink/1stLevel/sub-02/con_0002.nii
# 200731-13:33:35,877 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/con_0003.nii -> /output/datasink/1stLevel/sub-02/con_0003.nii
# 200731-13:33:35,879 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/con_0004.nii -> /output/datasink/1stLevel/sub-02/con_0004.nii
# 200731-13:33:35,881 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/con_0005.nii -> /output/datasink/1stLevel/sub-02/con_0005.nii
# 200731-13:33:35,882 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/ess_0006.nii -> /output/datasink/1stLevel/sub-02/ess_0006.nii
# 200731-13:33:35,884 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/spmF_0006.nii -> /output/datasink/1stLevel/sub-02/spmF_0006.nii
# 200731-13:33:35,886 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_02/ess_0006.nii -> /output/datasink/1stLevel/sub-02/ess_0006.nii
# 200731-13:33:35,890 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:33:37,263 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 200731-13:33:37,788 nipype.workflow INFO:
# 	 [Job 68] Completed (l1analysis.level1conest).
# 200731-13:33:37,791 nipype.workflow INFO:
# 	 [Job 62] Completed (l1analysis.datasink).
# 200731-13:33:37,795 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 226.64/226.64, Free processors: 4/4.
# 200731-13:33:37,857 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/output/workingdir/l1analysis/_subject_id_01/datasink".
# 200731-13:33:37,868 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200731-13:33:37,870 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/SPM.mat -> /output/datasink/1stLevel/sub-01/SPM.mat
# 200731-13:33:37,872 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/spmT_0001.nii -> /output/datasink/1stLevel/sub-01/spmT_0001.nii
# 200731-13:33:37,874 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/spmT_0002.nii -> /output/datasink/1stLevel/sub-01/spmT_0002.nii
# 200731-13:33:37,876 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/spmT_0003.nii -> /output/datasink/1stLevel/sub-01/spmT_0003.nii
# 200731-13:33:37,878 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/spmT_0004.nii -> /output/datasink/1stLevel/sub-01/spmT_0004.nii
# 200731-13:33:37,880 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/spmT_0005.nii -> /output/datasink/1stLevel/sub-01/spmT_0005.nii
# 200731-13:33:37,882 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/spmF_0006.nii -> /output/datasink/1stLevel/sub-01/spmF_0006.nii
# 200731-13:33:37,883 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/con_0001.nii -> /output/datasink/1stLevel/sub-01/con_0001.nii
# 200731-13:33:37,885 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/con_0002.nii -> /output/datasink/1stLevel/sub-01/con_0002.nii
# 200731-13:33:37,887 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/con_0003.nii -> /output/datasink/1stLevel/sub-01/con_0003.nii
# 200731-13:33:37,889 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/con_0004.nii -> /output/datasink/1stLevel/sub-01/con_0004.nii
# 200731-13:33:37,890 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/con_0005.nii -> /output/datasink/1stLevel/sub-01/con_0005.nii
# 200731-13:33:37,892 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/ess_0006.nii -> /output/datasink/1stLevel/sub-01/ess_0006.nii
# 200731-13:33:37,894 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/spmF_0006.nii -> /output/datasink/1stLevel/sub-01/spmF_0006.nii
# 200731-13:33:37,896 nipype.interface INFO:
# 	 sub: /output/datasink/1stLevel/_subject_id_01/ess_0006.nii -> /output/datasink/1stLevel/sub-01/ess_0006.nii
# 200731-13:33:37,900 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 200731-13:33:39,789 nipype.workflow INFO:
# 	 [Job 69] Completed (l1analysis.datasink).
# 200731-13:33:39,794 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 226.64/226.64, Free processors: 4/4.

# %%
#Crashs information is stored in .pklz files
# In case of a crash use the following command
#!nipypecli crash <Last generated .pklz file>

# %% [markdown]
# ## Inspect output
#
# Let's check the structure of the output folder, to see if we have everything we wanted to save. You should one image for each subject and contrast (``con_*.nii`` for T-contrasts and ``ess_*.nii`` for F-contrasts)

# %%
# !tree /output/datasink/1stLevel
# Out:
# /output/datasink/1stLevel
# ├── sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-02
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-03
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-04
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-05
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-06
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-07
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-08
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# ├── sub-09
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── con_0004.nii
# │   ├── con_0005.nii
# │   ├── ess_0006.nii
# │   ├── spmF_0006.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   ├── spmT_0003.nii
# │   ├── spmT_0004.nii
# │   └── spmT_0005.nii
# └── sub-10
#     ├── con_0001.nii
#     ├── con_0002.nii
#     ├── con_0003.nii
#     ├── con_0004.nii
#     ├── con_0005.nii
#     ├── ess_0006.nii
#     ├── spmF_0006.nii
#     ├── SPM.mat
#     ├── spmT_0001.nii
#     ├── spmT_0002.nii
#     ├── spmT_0003.nii
#     ├── spmT_0004.nii
#     └── spmT_0005.nii
#
# 10 directories, 130 files

# %% [markdown]
# ## Visualize results
#
# Let's look at the contrasts of one subject that we've just computed.

# %%
from nilearn.plotting import plot_stat_map

#Reminder the tests were 
test_to_number = {
    1: 'average',
    2: 'Finger',
    3: 'Foot',
    4: 'Lips',
    5: 'Foot > others',
    6: 'activation'
    }
subject_id = '01'
anatimg = f'/data/ds000114/derivatives/fmriprep/sub-{subject_id}/anat/sub-{subject_id}_t1w_preproc.nii.gz'

# %%
subject_id = '05'
 
anatimg = f'/data/ds000114/derivatives/fmriprep/sub-{subject_id}/anat/sub-{subject_id}_t1w_preproc.nii.gz'
for contrast_id in range(1, 6):
    plot_stat_map(
        f'/output/datasink/1stLevel/sub-{subject_id}/spmT_000{contrast_id}.nii', title=test_to_number[contrast_id],
        bg_img=anatimg, threshold=3, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %%
contrast_id = 6
subject_id = '09'

plot_stat_map(
        f'/output/datasink/1stLevel/sub-{subject_id}/spmF_000{contrast_id}.nii', title=test_to_number[contrast_id],
        bg_img=anatimg, threshold=3, display_mode='y', cut_coords=(-5, 0, 5, 10, 15), dim=-1);

# %% [markdown]
# To add thanks to ...
